# %% [markdown]
# # TF-IDF
#
# The goal of this analysis is to find how humanitarian is used in combination with other important words in the corpus. The results from this exercise will be represented on a map that joins countries using arrow lines. This visualisation answers the data holder's question regarding the direction of humanitarian aid.

# %%
# Import the necessary libraries
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd # For dataframe analysis
import numpy as np
import re # Regix to remove punctuation from strings I split
import requests # To get Lat Long via API Request
import urllib.parse

# %%
# Declare variables
yearMonths = ['201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008']
yearMonthsWord = ['Dec 2019', 'Jan 2020', 'Feb 2020', 'Mar 2020', 'Apr 2020', 'May 2020', 'Jun 2020', 'Jul 2020', 'Aug 2020']
countryGroup = ['Gulf Countries', 'Euro-Atlantic Countries', 'New Global Media Players']

# %%
# Get stopwords and initiate vectorizer
tfidf = TfidfVectorizer(stop_words='english')

# %% [markdown]
# ## Functions
#
# Declaring important functions at the top so I can call them later.

# %%
def get_top_tf_idf_words(response, top_n=3):
    sorted_nzs = np.argsort(response.data)[:-(top_n+1):-1]
    return feature_names[response.indices[sorted_nzs]]

def cleanTextInDf(mystring):
    mystring = mystring.lower() # Text normalization: make string lowercase
    mystring = re.sub(r'[^\w\s]','', mystring) # Text normalization: remove punctuation
    return mystring

def checkYearMonth(row):
    value = row['date']
    return str(value)[0:6]

# def customTfidf(term, corpus):
#     corpusLen = len(corpus)
#     trainingLen = corpusLen * 0.2 # Train it on 20% of the text items
#     trainingLen = int(trainingLen)
#     trainArr = corpus[:trainingLen] # First 20% of corpus
#     restArr = corpus[-(len(corpus)-trainingLen-2):] # Last 80% of corpus
#     X = tfidf.fit_transform(trainArr)
#     feature_names = np.array(tfidf.get_feature_names())
#     responses = tfidf.transform(restArr)
#     resultsArr = [get_top_tf_idf_words(response,2) for response in responses]
#     return [l.tolist() for l in resultsArr]

# %%
# Get CSV data and combine it into a dataframe

ae_df = pd.read_csv('Clean Data/AE_cleandf.csv')
cn_df = pd.read_csv('Clean Data/CN_cleandf.csv')
de_df = pd.read_csv('Clean Data/DE_cleandf.csv')
fr_df = pd.read_csv('Clean Data/FR_cleandf.csv')
ir_df = pd.read_csv('Clean Data/IR_cleandf.csv')
kw_df = pd.read_csv('Clean Data/KW_cleandf.csv')
qa_df = pd.read_csv('Clean Data/QA_cleandf.csv')
ru_df = pd.read_csv('Clean Data/RU_cleandf.csv')
sa_df = pd.read_csv('Clean Data/SA_cleandf.csv')
tr_df = pd.read_csv('Clean Data/TR_cleandf.csv')
uk_df = pd.read_csv('Clean Data/UK_cleandf.csv')
us_df = pd.read_csv('Clean Data/US_cleandf.csv')
df = pd.concat([ae_df, cn_df, de_df, fr_df, ir_df, kw_df, qa_df, ru_df, sa_df, tr_df, uk_df, us_df], ignore_index=True)

# %%
# Clean the dataframe
cleanText = lambda text: cleanTextInDf(text) # Lambda function applies to all cells in a column
cleandf = pd.DataFrame(df.text.apply(cleanText)) # .apply() the function to all cells
df['text'] = cleandf['text']
df['yearmonth'] = df.apply(checkYearMonth, axis=1)
df
# Out:
#                                               name  \
# 0      20200619_AE_EmiratesNewsAgency_NEXIS212.txt
# 1            20200422_AE_AlArabiya_FACTIVA2484.txt
# 2          20200328_AE_TheNational_GDELT136558.txt
# 3             20200616_AE_KhaleejTimes_NEXIS59.txt
# 4           20200318_AE_TheNational_NEXIS18486.txt
# ...                                            ...
# 13426    20200402_US_AssociatedPress_SERP11978.txt
# 13427  20200629_US_TheNewYorkTimes_NEXIS794361.txt
# 13428               20200520_US_CNN_GNAPI69344.txt
# 13429              20200402_US_VOA_GDELT131430.txt
# 13430               20200424_US_VOA_GNAPI66901.txt
#
#                                                     path country  \
# 0      Raw text/AEClean/20200619_AE_EmiratesNewsAgenc...      AE
# 1      Raw text/AEClean/20200422_AE_AlArabiya_FACTIVA...      AE
# 2      Raw text/AEClean/20200328_AE_TheNational_GDELT...      AE
# 3      Raw text/AEClean/20200616_AE_KhaleejTimes_NEXI...      AE
# 4      Raw text/AEClean/20200318_AE_TheNational_NEXIS...      AE
# ...                                                  ...     ...
# 13426  Raw text/USClean/20200402_US_AssociatedPress_S...      US
# 13427  Raw text/USClean/20200629_US_TheNewYorkTimes_N...      US
# 13428    Raw text/USClean/20200520_US_CNN_GNAPI69344.txt      US
# 13429   Raw text/USClean/20200402_US_VOA_GDELT131430.txt      US
# 13430    Raw text/USClean/20200424_US_VOA_GNAPI66901.txt      US
#
#                   network      date  token_freq  \
# 0      EmiratesNewsAgency  20200619           4
# 1               AlArabiya  20200422          13
# 2             TheNational  20200328          10
# 3            KhaleejTimes  20200616           3
# 4             TheNational  20200318          16
# ...                   ...       ...         ...
# 13426     AssociatedPress  20200402           5
# 13427     TheNewYorkTimes  20200629          13
# 13428                 CNN  20200520          18
# 13429                 VOA  20200402          22
# 13430                 VOA  20200424           3
#
#                                                     text yearmonth
# 0      melbourne 18th june 2020 wam the uae general c...    202006
# 1      020 al arabiya all rights reserved provided by...    202004
# 2      uae offers to help syria counter coronavirus t...    202003
# 3      loréal middle east has launched a uae solidari...    202006
# 4      medical staff push a patient on a gurney to a ...    202003
# ...                                                  ...       ...
# 13426  world food program usa allocates 333000 in eme...    202004
# 13427  the country has been hit with a triplewhammy r...    202006
# 13428  cnnchinese leader xi jinping made preserving d...    202005
# 13429  washington north koreas decision to protect it...    202004
# 13430  addis ababa travel restrictions meant to slow ...    202004
#
# [13431 rows x 8 columns]

# %% [markdown]
# ## Test run with US
#
# Testing the TF-IDF algorithm with one country before I map it to the block of countries.

# %%
# make a list from the text column of US articles
dfUs = df[df['country']=='US']
arr = dfUs["text"].to_numpy()
arr = arr.tolist()

# %%
# Train and run TF-IDF

corpus = arr
corpusLen = len(corpus)
trainingLen = corpusLen * 0.2 # Train it on 20% of the text items
trainingLen = int(trainingLen)
trainArr = corpus[:trainingLen] # First 20% of corpus
restArr = corpus[-(len(corpus)-trainingLen-4):] # Last 80% of corpus
X = tfidf.fit_transform(trainArr)
feature_names = np.array(tfidf.get_feature_names())
responses = tfidf.transform(restArr)
resultsArr = [get_top_tf_idf_words(response,4) for response in responses]
finalArr = [l.tolist() for l in resultsArr]

# %%
# Print items with 'interesting keywords' only. Note, we are only interested in knowing about aid and support

for item in finalArr:
    for subitem in item:
        if subitem in interestingKeywords:
            print(item)
# Out:
# ['groups', 'rumours', 'aid', 'migrants']
# ['aid', 'border', 'ngos', 'asylum']
# ['updated', 'april', 'aid', 'migrants']
# ['idlib', 'province', 'groups', 'aid']
# ['faso', 'burkina', 'registration', 'aid']
# ['yemen', 'houthis', 'yemens', 'aid']
# ['donated', 'japan', 'yen', 'center']
# ['vegas', 'las', 'nevada', 'donation']
# ['tnh', 'aid', 'victims', 'samoa']
# ['yemen', 'aid', 'lowcock', 'email']
# ['usaid', 'programs', 'aid', 'foreign']
# ['billion', 'aid', 'grants', 'spending']
# ['aid', 'funding', 'generosity', 'administration']
# ['cross', 'red', 'donations', 'party']
# ['shop', 'donated', 'retailer', 'donate']
# ['shop', 'donated', 'retailer', 'donate']
# ['pakistan', 'aid', 'pakistans', 'groups']
# ['yemen', 'aid', 'houthis', 'uae']
# ['yemen', 'houthis', 'aid', 'programs']
# ['aid', 'yemen', 'rebels', 'programs']
# ['yemen', 'houthis', 'aid', 'programs']
# ['yemen', 'wfp', 'yemeni', 'aid']
# ['funding', 'aid', 'billion', 'spending']
# ['aid', 'relief', 'money', 'agency']
# ['advertisement', 'aid', 'relief', 'money']
# ['3m', 'supplies', 'respirators', 'medical']
# ['aid', 'commitments', 'analysis', 'funding']
# ['aid', '26', 'march', 'ngos']
# ['china', 'donated', 'air', 'flight']
# ['ap', 'venezuela', 'aid', 'nations']
# ['masks', 'n95', 'shipments', 'medical']
# ['aid', 'sanaa', 'houthi', 'yemen']
# ['yemen', 'aid', 'houthis', 'uae']
# ['aid', 'commitments', 'analysis', 'funding']
# ['aid', 'conversation', 'audience', 'readers']
# ['department', 'assistance', 'aid', '64']
# ['iran', 'yemen', 'aid', 'usaid']
# ['aid', 'agency', 'feet', 'funding']
# ['aid', 'analysis', 'commitments', 'billion']
# ['aid', 'ngos', 'programmes', 'ngo']
# ['masks', 'n95', 'shipments', 'medical']
# ['yemen', 'aid', 'pledges', 'war']
# ['sector', 'aid', 'organisations', 'humanitarians']
# ['mutual', 'nhs', 'aid', 'volunteers']
# ['usaid', 'ppe', 'supplies', 'aid']
# ['aid', 'yemen', 'rebels', 'programs']
# ['updated', 'programmes', 'aid', 'april']
# ['russia', 'moscow', 'medical', 'kremlin']
# ['equipment', 'schaffner', 'medical', 'russia']
# ['food', 'rations', 'yemen', 'aid']
# ['aid', 'agency', 'funding', 'protective']
# ['masks', 'n95', 'shipments', 'medical']
# ['aid', 'relief', 'money', 'agency']
# ['aid', 'funding', 'generosity', 'administration']
# ['aid', 'maxman', 'panelists', 'oxfam']
# ['iran', 'yemen', 'aid', 'reported']
# ['yemen', 'houthis', 'aid', 'yemens']
# ['humanitarians', 'aid', 'change', 'ngos']
# ['trust', 'ebola', 'aid', 'mistrust']
# ['syria', 'russia', 'syrians', 'aid']
# ['crossing', 'mandate', 'northwest', 'aid']
# ['masks', 'n95', 'shipments', 'medical']
# ['kay', 'mary', 'sanitizer', 'donated']
# ['fontaine', 'says', 'aid', 'countries']
# ['sporting', 'golf', 'goods', 'donation']
# ['yemen', 'aid', 'pledges', 'war']
# ['taiwan', 'taiwans', 'masks', 'donating']
# ['novel', 'medical', 'wuhan', 'feb']
# ['aid', 'commitments', 'analysis', 'funding']
# ['donated', 'million', 'company', 'york']
# ['medical', 'quality', 'export', 'respirators']
# ['funding', 'aid', 'assistance', 'critical']
# ['frances', 'aid', 'moeti', 'continent']
# ['northeast', 'bab', 'northwest', 'aid']
# ['crossing', 'mandate', 'northwest', 'aid']

# %%
finalArr
# Out:
# [['vaccines', 'china', 'medicines', 'vaccine'],
#  ['irgc', 'device', 'jahanpur', 'iranian'],
#  ['moscow', 'reset', 'kremlin', 'treaty'],
#  ['canada', '3m', 'n95', 'masks'],
#  ['indias', 'villages', 'walking', 'kilometers'],
#  ['libya', 'hifter', 'dujarric', 'pause'],
#  ['food', 'hunger', 'farmers', 'global'],
#  ['brewer', 'pastors', 'bhargava', 'cuba'],
#  ['afghanistan', 'deliberate', 'kabul', 'afghan'],
#  ['mogadishu', 'somalia', 'mohamed', 'ali'],
#  ['weather', 'assume', 'romania', 'fauci'],
#  ['north', 'korean', 'korea', 'news'],
#  ['groups', 'rumours', 'aid', 'migrants'],
#  ['iran', 'sanctions', 'iranian', 'hardliners'],
#  ['___', 'says', 'lockdown', 'india'],
#  ['camps', 'refugee', 'camp', 'refugees'],
#  ['health', 'global', 'methodist', 'social'],
#  ['yemen', 'saeed', 'initiative', 'hayel'],
#  ['venezuelan', 'venezuela', 'maduro', 'caracas'],
#  ['iran', 'sanctions', 'iranianbacked', 'iraq'],
#  ['robots', 'robotics', 'yang', 'robot'],
#  ['friday', 'sanofi', 'said', 'tests'],
#  ['aid', 'border', 'ngos', 'asylum'],
#  ['vetoed', 'council', 'amendment', 'continuation'],
#  ['heroes', 'act', 'stimulus', 'senate'],
#  ['gaza', 'israel', 'gazas', 'palestinian'],
#  ['ocasiocortez', 'tlaib', 'omar', 'squad'],
#  ['bank', 'clients', 'union', 'branches'],
#  ['gaza', 'usaid', 'palestinian', 'crs'],
#  ['amanpour', 'facebook', 'black', 'think'],
#  ['francine', 'think', 'bloomberg', 'tom'],
#  ['edison', 'community', 'ventura', 'county'],
#  ['oxfam', 'hunger', 'hotspots', 'oxfams'],
#  ['pakistan', 'refugees', 'baloch', 'iran'],
#  ['brazil', 'argentina', 'brazilian', 'argentine'],
#  ['pompeo', 'evidence', 'wuhan', 'stares'],
#  ['lebanon', 'lockdown', 'abiad', 'restrictions'],
#  ['think', 'bernie', 'know', 'going'],
#  ['women', 'msf', 'maternity', 'afghanistan'],
#  ['brazil', 'brazilian', 'argentine', 'argentina'],
#  ['newman', 'ms', 'wedding', 'mr'],
#  ['canada', 'canadian', 'pulp', 'canadians'],
#  ['says', 'displaced', 'diseases', 'unhcr'],
#  ['hadis', 'stc', 'aden', 'southern'],
#  ['california', 'sacramento', 'newsom', 'food'],
#  ['bab', 'resolution', 'crossing', 'alhawa'],
#  ['laguna', 'woods', 'passover', 'editorial'],
#  ['ceremony', 'driveup', 'budget', 'graduation'],
#  ['syria', 'border', 'bus', 'journalists'],
#  ['crossing', 'northwest', 'mandate', 'enclave'],
#  ['appeal', 'africa', 'african', 'macron'],
#  ['resorts', 'ski', 'vail', 'resort'],
#  ['beasley', 'wfp', 'sudan', 'food'],
#  ['___', 'masks', 'korea', 'south'],
#  ['trump', 'mr', 'president', 'governors'],
#  ['resolution', 'syria', 'crossings', 'sites'],
#  ['scams', 'ftc', 'cures', '3m'],
#  ['hernández', 'honduras', 'said', 'hospital'],
#  ['passengers', 'rotterdam', 'zaandam', 'crew'],
#  ['migrants', 'yemen', 'iom', 'ethiopians'],
#  ['korea', 'north', 'korean', 'defector'],
#  ['ebola', 'responders', 'survivors', 'congo'],
#  ['chatterley', 'think', 'loans', 'julia'],
#  ['mr', 'virus', 'trump', 'china'],
#  ['yemen', 'saeed', 'initiative', 'hayel'],
#  ['3m', 'masks', 'respirators', 'n95'],
#  ['african', 'flights', 'africa', 'seychelles'],
#  ['camerota', 'berman', 'sidner', 'gigi'],
#  ['latin', 'peru', 'argentina', 'marcos'],
#  ['ips', 'global', 'journalists', 'contributors'],
#  ['iran', 'tehran', 'nuclear', 'sanctions'],
#  ['russia', 'draft', 'bab', 'council'],
#  ['apps', 'drug', 'china', 'heres'],
#  ['ship', 'sydney', 'crew', 'perth'],
#  ['climate', 'resilience', 'disasters', 'communities'],
#  ['north', 'korea', 'choi', 'koreas'],
#  ['resolution', 'months', 'hostilities', 'adopt'],
#  ['updated', 'april', 'aid', 'migrants'],
#  ['sentence', 'prison', 'steve', 'patti'],
#  ['sanctions', 'eu', 'consequences', 'gaza'],
#  ['___', 'cases', 'wednesday', 'wear'],
#  ['northeast', 'crossing', 'syria', 'kurdish'],
#  ['north', 'korea', 'exemption', 'ifrc'],
#  ['hutchinson', 'arkansas', 'smith', 'file'],
#  ['immigration', 'uscis', 'ice', 'enforcement'],
#  ['passengers', 'zaandam', 'florida', 'fort'],
#  ['mariners', 'navy', 'civilian', 'ships'],
#  ['pic', 'politico', 'campaign', 'loans'],
#  ['africa', 'kenya', 'moeti', 'alcohol'],
#  ['idlib', 'province', 'groups', 'aid'],
#  ['irc', 'testing', 'africa', 'positivity'],
#  ['specials', 'gods', 'colombian', 'dispatches'],
#  ['ecw', 'education', 'children', 'refugee'],
#  ['school', 'cases', 'california', 'students'],
#  ['care', 'child', 'watt', 'caregiving'],
#  ['harris', 'church', 'taiwan', 'rosemary'],
#  ['libya', 'agencies', 'hifter', 'detention'],
#  ['lukashenko', 'heres', 'attack', 'father'],
#  ['north', 'korea', 'koreas', 'koreans'],
#  ['subscribe', 'newsletter', 'updates', 'track'],
#  ['autism', 'bertini', 'women', 'zoom'],
#  ['immigrants', 'taxpayers', 'undocumented', 'irs'],
#  ['hifter', 'tripoli', 'libya', 'forces'],
#  ['april', 'masks', 'protective', 'coronavirus'],
#  ['pandemic', 'virus', 'countries', 'regions'],
#  ['resolution', 'council', 'diplomats', 'draft'],
#  ['tripoli', 'hifter', 'libya', 'drones'],
#  ['refugee', 'dhs', 'arrivals', 'implementing'],
#  ['faso', 'burkina', 'registration', 'aid'],
#  ['says', 'north', 'food', 'quintana'],
#  ['___', 'korea', 'masks', 'said'],
#  ['ethics', 'ethical', 'emergency', 'virtues'],
#  ['health', 'percent', 'paho', 'beds'],
#  ['camps', 'coxs', 'bazar', 'rohingya'],
#  ['council', 'nations', 'guterres', 'mr'],
#  ['masks', 'n95', 'grady', 'ray'],
#  ['health', 'funding', 'organization', 'communicable'],
#  ['qanon', 'mitchell', 'bubble', 'jones'],
#  ['solutions', 'group', 'cargo', 'aviation'],
#  ['caroline', 'taylor', 'snap', 'revenue'],
#  ['migrants', 'tripoli', 'libyan', 'rescue'],
#  ['yemen', 'griffiths', 'lowcock', 'yemeni'],
#  ['hydroxychloroquine', 'drug', 'export', 'ban'],
#  ['turkey', 'ankara', 'satterfield', 'fahrettin'],
#  ['sailors', 'wednesday', 'netanyahu', 'said'],
#  ['cnn', 'church', 'videotape', 'acosta'],
#  ['aden', 'yemeni', 'yemen', 'selfrule'],
#  ['moria', 'camp', 'asylum', 'seekers'],
#  ['abc', 'ian', 'voiceover', 'seema'],
#  ['comfort', 'usns', 'ship', 'york'],
#  ['lemon', 'noose', 'nascar', 'garage'],
#  ['gaza', 'yemen', 'cases', 'health'],
#  ['wuhan', 'consulate', 'airport', 'evacuation'],
#  ['cathedral', 'cathedrals', 'daniel', 'church'],
#  ['said', 'tuesday', 'cases', 'coronavirus'],
#  ['li', 'lu', 'foundation', 'wuhan'],
#  ['sinaloa', 'mountains', 'violence', 'lópez'],
#  ['venezuelans', 'bogota', 'colombia', 'venezuela'],
#  ['gayle', 'mason', 'yeah', 'duncan'],
#  ['cnn', 'church', 'trump', 'weinstein'],
#  ['genesis', 'prize', 'jewish', 'grants'],
#  ['vaccine', 'vaccines', 'health', 'pool'],
#  ['beirut', 'blast', 'explosion', 'lebanese'],
#  ['africa', 'countries', 'african', 'nations'],
#  ['ebola', 'laerke', 'tackle', 'drc'],
#  ['nightclubs', 'italian', 'colombian', 'linked'],
#  ['foundation', 'soros', 'million', 'mr'],
#  ['epidemic', 'realtime', 'peoples', 'hong'],
#  ['eu', 'bloc', 'brussels', 'european'],
#  ['yeargan', 'tan', 'singapore', 'said'],
#  ['india', 'china', 'chinese', 'beijing'],
#  ['indias', 'india', 'delhi', 'nadu'],
#  ['nigeria', 'oil', 'nigerian', 'crude'],
#  ['abroad', 'visas', 'inbound', 'notice'],
#  ['sciutto', 'harlow', 'miliband', 'kids'],
#  ['inslee', 'seattle', 'said', 'king'],
#  ['bangladesh', 'rohingya', 'cox', 'bazar'],
#  ['ship', 'braemar', 'passengers', 'bahamas'],
#  ['cuomo', 'right', 'going', 'jha'],
#  ['gorani', 'kafanov', 'robertson', 'clip'],
#  ['forwardlooking', 'technology', 'defence', 'australia'],
#  ['vause', 'plastic', 'cnn', 'think'],
#  ['louvre', 'italy', 'visitors', 'france'],
#  ['river', 'bangladesh', 'flooding', 'climate'],
#  ['died', 'johns', 'hopkins', 'protested'],
#  ['yemen', 'houthis', 'yemens', 'aid'],
#  ['distillery', 'sanitizer', 'distillers', 'hand'],
#  ['vause', 'barr', 'know', 'cnn'],
#  ['gorani', 'hala', 'voiceover', 'ardern'],
#  ['north', 'korea', 'korean', 'diseasecontrol'],
#  ['yemen', 'brennan', 'abc', 'ceasefire'],
#  ['continent', 'africa', 'middleincome', 'tourism'],
#  ['scottish', 'tripoli', 'libya', 'charges'],
#  ['personnel', 'security', 'trump', 'national'],
#  ['korea', 'jung', 'min', 'seoul'],
#  ['pedersen', 'curfew', 'relaxed', 'altamimi'],
#  ['unidentified', 'male', 'know', 'pompeo'],
#  ['cyprus', 'tourism', 'folded', 'napa'],
#  ['embassy', 'afghans', 'kabul', 'afghanistan'],
#  ['chinese', 'china', 'masks', 'passenger'],
#  ['benefits', 'unemployment', 'says', 'insurance'],
#  ['arab', '57', 'survival', 'countries'],
#  ['north', 'panel', 'korea', 'nuclear'],
#  ['mr', 'biden', 'ebola', 'klain'],
#  ['zimbabwe', 'zimbabwes', 'zimbabweans', 'doctors'],
#  ['disability', 'disabilities', 'ndi', 'chronic'],
#  ['lauren', 'india', 'choudhury', 'hydroxychloroquine'],
#  ['abortion', 'clinic', 'pill', 'access'],
#  ['hong', 'kong', 'estate', 'think'],
#  ['melber', 'ari', 'friedman', 'raven'],
#  ['japan', 'japanese', 'foreigners', 'stranded'],
#  ['brunei', 'sea', 'china', 'malaysia'],
#  ['wyatt', 'detainees', 'ice', 'goldstein'],
#  ['laerke', 'yemen', '2nd', 'aden'],
#  ['think', 'fed', 'know', 'going'],
#  ['children', 'burkina', 'violence', 'martine'],
#  ['venezuelans', 'bogota', 'colombia', 'venezuela'],
#  ['ice', 'parole', 'flores', 'parents'],
#  ['religious', 'religions', 'peace', 'ircs'],
#  ['gaza', 'strip', 'israel', 'gazas'],
#  ['syria', 'iraq', 'nato', 'voa'],
#  ['amanpour', 'spending', 'know', 'sreenivasan'],
#  ['hoover', 'doesn', '1932', 'herbert'],
#  ['cases', 'new', 'said', 'vietnam'],
#  ['united', 'coalition', 'states', 'ebola'],
#  ['asgari', 'mr', 'iran', 'iranian'],
#  ['cuban', 'cuba', 'ecuador', 'doctors'],
#  ['republicans', 'measure', 'gop', 'trillion'],
#  ['cooper', 'individuals', 'broward', 'iowa'],
#  ['houthis', 'saudi', 'rebels', 'drones'],
#  ['queen', 'thursday', 'sailor', 'taiwan'],
#  ['goma', 'kivu', 'ebola', 'kinshasa'],
#  ['anderson', 'unidentified', 'clip', 'becky'],
#  ['emirates', 'citizens', 'uae', 'dhabi'],
#  ['sanctions', 'maduro', 'venezuelan', 'iran'],
#  ['pacific', 'islands', 'mariner', 'samoa'],
#  ['holyoke', 'netanyahu', 'sailors', 'wednesday'],
#  ['kashmir', 'women', 'violence', 'womens'],
#  ['water', 'customers', 'grants', 'partners'],
#  ['ceasefire', 'gowan', 'said', 'conflict'],
#  ['abrams', 'venezuela', 'maduro', 'mr'],
#  ['bosnia', 'graft', 'imported', 'ventilators'],
#  ['andrés', 'emilio', 'india', 'think'],
#  ['iran', 'tehran', 'bbc', 'regime'],
#  ['ice', 'detention', 'detainees', 'facilities'],
#  ['guard', 'members', 'martial', 'lengyel'],
#  ['baghdad', 'iraq', 'iraqi', 'iran'],
#  ['ukraine', 'impeachment', 'zelensky', 'volodymyr'],
#  ['china', '2003', 'chinas', 'beijings'],
#  ['hunger', 'malnutrition', 'action', 'reception'],
#  ['state', 'said', 'department', 'monday'],
#  ['vaccine', 'trials', 'oxford', 'south'],
#  ['camps', 'cox', 'bazar', 'ripe'],
#  ['truck', 'colombia', 'bogotá', 'overturned'],
#  ['cambodia', 'passengers', 'hun', 'wonderful'],
#  ['syria', 'northeastern', 'qamishli', 'fighters'],
#  ['blasio', 'purse', 'samaritan', 'graham'],
#  ['macron', 'guterres', 'uk', 'ceasefire'],
#  ['aden', 'suspected', 'said', 'doctors'],
#  ['griffiths', 'houthis', 'yemen', 'ceasefire'],
#  ['economies', 'developing', 'bank', 'advanced'],
#  ['omar', 'ilhan', 'fifth', 'gouging'],
#  ['israel', 'palestinian', 'gaza', 'palestinians'],
#  ['migrants', 'italy', 'conte', 'decree'],
#  ['debt', 'creditors', 'ethiopia', 'moratorium'],
#  ['legislatures', 'legislature', 'vote', 'statewide'],
#  ['taliban', 'groups', 'cartels', 'armed'],
#  ['diabetes', 'outcomes', 'association', 'insulin'],
#  ['marshall', 'africa', 'continent', 'plan'],
#  ['iran', 'franks', 'evacuation', 'furlough'],
#  ['clip', 'church', 'video', 'netanyahu'],
#  ['theater', 'stories', 'nelson', 'isnt'],
#  ['africa', 'countries', 'african', 'ventilators'],
#  ['organization', 'letter', 'world', 'funding'],
#  ['andrés', 'kitchen', 'central', 'feeding'],
#  ['food', 'insects', 'farmers', 'africa'],
#  ['yemenis', 'yemen', 'workers', 'doctors'],
#  ['workers', 'migrant', 'dormitories', 'singapore'],
#  ['cough', 'pg', 'formula', 'congestion'],
#  ['organisations', 'refugees', 'refugee', 'urban'],
#  ['resolution', 'council', 'draft', 'gowan'],
#  ['cdfis', 'bank', 'clients', 'america'],
#  ['haiti', 'portauprince', 'tnh', 'haitians'],
#  ['shery', 'hong', 'kong', 'market'],
#  ['masks', 'trade', 'bown', 'china'],
#  ['ap', 'georgia', 'black', 'atlanta'],
#  ['ceasefire', 'gowan', 'lili', 'armed'],
#  ['savannah', 'guthrie', 'hoda', 'kotb'],
#  ['kanye', 'rapper', 'ap', 'birthdays'],
#  ['uzbekistans', 'uzbekistan', 'patients', 'health'],
#  ['___', 'friday', 'inmate', 'albania'],
#  ['olympics', 'lowcock', 'easing', 'declining'],
#  ['odonnell', 'mail', 'caste', 'isabel'],
#  ['migrants', 'sea', 'desert', 'libya'],
#  ['romaine', 'caroline', 'market', 'blackrock'],
#  ['garcetti', 'beach', 'parking', 'california'],
#  ['malnutrition', 'malnourished', 'wasting', 'food'],
#  ['women', 'girls', 'gender', 'ips'],
#  ['tarhuna', 'hifters', 'tripoli', 'forces'],
#  ['iran', 'sanctions', 'tehran', 'rouhani'],
#  ['pompeo', 'department', 'staffers', 'employees'],
#  ['kabul', 'afghanistan', 'fear', 'calculations'],
#  ['clashes', 'alshabab', 'week', 'recent'],
#  ['syria', 'npr', 'worker', 'syrian'],
#  ['ebola', 'congo', 'said', 'newport'],
#  ['ships', 'holland', 'passengers', 'broward'],
#  ['gang', 'africa', 'alcohol', 'south'],
#  ['antibody', 'tests', 'swab', 'venezuela'],
#  ['exercises', 'military', 'troops', 'gaza'],
#  ['iran', 'iranian', 'sanctions', 'china'],
#  ['brazil', 'argentina', 'brazilian', 'argentine'],
#  ['nebenzia', 'astana', 'ceasefire', 'syria'],
#  ['tarhuna', 'hifters', 'forces', 'tripoli'],
#  ['ai', 'film', 'weiwei', 'exile'],
#  ['appeal', 'guterres', 'secretarygeneral', 'developing'],
#  ['returnees', 'deportees', 'voluntary', 'iom'],
#  ['pompeo', 'hannity', 'data', 'iran'],
#  ['hayes', 'know', 'people', 'just'],
#  ['fedex', 'express', 'shipments', 'ppe'],
#  ['phillips', 'ebola', 'says', 'nurses'],
#  ['frieden', 'said', 'adalja', 'health'],
#  ['partner', 'assistance', 'richardson', 'implementing'],
#  ['trump', 'publichealth', 'briefing', 'monday'],
#  ['cuomo', 'blasio', 'governor', 'mayor'],
#  ['haiti', 'pape', 'says', 'haitians'],
#  ['zaandam', 'broward', 'passengers', 'ships'],
#  ['cnn', 'spain', 'wieler', 'nhs'],
#  ['chi', 'swann', 'normal', 'said'],
#  ['turkey', 'ankara', 'satterfield', 'fahrettin'],
#  ['myanmars', 'kachin', 'camps', 'displaced'],
#  ['___', 'cases', 'birx', 'says'],
#  ['china', 'chang', 'fox', 'visas'],
#  ['islands', 'pacific', 'accessed', 'women'],
#  ['fema', 'regulation', 'cbp', 'materials'],
#  ['myanmars', 'abiy', 'food', 'rakhine'],
#  ['abc', 'tom', 'voiceover', 'tonight'],
#  ['anderson', 'jordan', 'netanyahu', 'israel'],
#  ['irc', 'genderbased', 'women', 'girls'],
#  ['babies', 'mothers', 'afghan', 'kabul'],
#  ['doherty', 'spahn', 'trump', 'health'],
#  ['northeast', 'syria', 'crossing', 'simpson'],
#  ['mohamad', 'fighters', 'captured', 'syria'],
#  ['blackwell', 'paul', 'christi', 'lujan'],
#  ['chinese', 'china', 'outbreak', 'mai'],
#  ['russia', 'visas', 'chinese', 'china'],
#  ['libya', 'dujarric', 'hifters', 'pause'],
#  ['rferl', 'prison', 'custody', 'historian'],
#  ['salt', 'china', 'supplies', 'uschina'],
#  ['alegre', 'perus', 'peru', 'exconvicts'],
#  ['zealand', 'says', 'tourism', 'new'],
#  ['pompeo', 'openness', 'billion', 'chinas'],
#  ['philadelphia', 'tyler', 'congregants', 'pews'],
#  ['mihigo', 'drc', 'said', 'measles'],
#  ['weapons', 'koreas', 'north', 'korea'],
#  ['alegre', 'peru', 'lima', 'exconvicts'],
#  ['gabaroni', 'zaandam', 'passengers', 'florida'],
#  ['india', 'kumar', 'slum', 'said'],
#  ['navajo', 'lujan', 'nation', 'grisham'],
#  ['uae', 'annexation', 'israel', 'arab'],
#  ['cipla', 'ciplas', 'gilead', 'remdesivir'],
#  ['liquor', 'wieler', 'institute', 'tuesday'],
#  ['iran', 'iranian', 'khamenei', 'virus'],
#  ['migrants', 'tripoli', 'sea', 'libyan'],
#  ['ventilator', 'canada', 'canadian', 'mobilization'],
#  ['performance', 'bryant', 'wayne', 'black'],
#  ['camp', 'says', 'refugees', 'refugee'],
#  ['indias', 'villages', 'walking', 'bags'],
#  ['korea', 'north', 'sanctions', 'korean'],
#  ['penn', 'core', 'sites', 'actor'],
#  ['3m', 'masks', 'roman', 'said'],
#  ['detainees', 'petitioners', 'respondents', 'ice'],
#  ['rotterdam', 'passengers', 'zaandam', 'board'],
#  ['hcq', 'trump', 'slidenext', 'slide'],
#  ['yemen', 'msf', 'sana', 'dying'],
#  ['___', 'cases', 'wednesday', 'new'],
#  ['museum', 'construction', 'lucas', 'youn'],
#  ['noel', 'barr', 'king', 'lucas'],
#  ['iran', 'soviet', 'constitutional', 'crossroads'],
#  ['displaced', 'yemen', 'iom', 'says'],
#  ['north', 'panel', 'korea', 'nuclear'],
#  ['lowcock', 'cuts', 'million', 'halving'],
#  ['homeless', 'sambadrome', 'rio', 'streets'],
#  ['state', 'gov', 'monday', 'coronavirus'],
#  ['bosnia', 'prosecutors', 'imported', 'owner'],
#  ['houthi', 'cemeteries', 'yemen', 'hospital'],
#  ['appeal', 'grandi', 'lowcock', 'said'],
#  ['debt', 'ethiopia', 'creditors', 'moratorium'],
#  ['people', 'governor', 'know', 'york'],
#  ['antibody', 'tests', 'swab', 'venezuela'],
#  ['nonprofit', 'sector', 'job', 'kids'],
#  ['donated', 'japan', 'yen', 'center'],
#  ['rakhine', 'myanmar', 'amnesty', 'indiscriminate'],
#  ['griffiths', 'houthis', 'yemen', 'ceasefire'],
#  ['cyclone', 'amphan', 'storm', 'indian'],
#  ['eloy', 'chilel', 'detainees', 'palma'],
#  ['china', 'entering', 'temporarily', 'visafree'],
#  ['___', 'wednesday', 'cases', 'new'],
#  ['inskeep', 'craft', 'kelly', 'steve'],
#  ['guaidó', 'lawmakers', 'opposition', 'venezuelan'],
#  ['constitutional', 'african', 'tenure', 'malawi'],
#  ['crammed', 'guterres', 'water', 'waves'],
#  ['japan', 'residents', 'japanese', 'reentry'],
#  ['idlib', 'syria', 'homemade', 'tent'],
#  ['writes', 'polio', 'vaccine', 'heres'],
#  ['said', 'leak', 'feroz', 'antibodies'],
#  ['fedex', 'china', 'wuhan', 'hub'],
#  ['navajo', 'solar', 'renewable', 'salt'],
#  ['melber', 'thats', 'going', 'president'],
#  ['distillery', 'sanitizer', 'distillers', 'hand'],
#  ['maduro', 'venezuela', 'guaidó', 'navy'],
#  ['refugees', 'family', 'afghanistan', 'job'],
#  ['detainees', 'ice', 'mesa', 'adelanto'],
#  ['iswap', 'rohingya', 'uighur', 'logo'],
#  ['percent', 'citizens', 'trust', 'africans'],
#  ['india', 'hydroxychloroquine', 'export', 'antimalarial'],
#  ['canadian', 'meng', 'canada', 'trade'],
#  ['muslims', 'hajj', 'mecca', 'kingdom'],
#  ['documentary', 'film', 'awards', 'academy'],
#  ['3m', 'canada', 'ontario', 'masks'],
#  ['toner', 'flu', 'publichealth', 'monaco'],
#  ['___', 'funeral', 'canberra', 'cases'],
#  ['jarrett', 'romans', 'clip', 'romney'],
#  ['food', 'says', 'farmers', 'rice'],
#  ['pink', 'cavanaugh', 'le', 'baking'],
#  ['labor', 'peshawar', 'child', 'khan'],
#  ['sudanese', 'stranded', 'iran', 'qatar'],
#  ['david', 'bloomberg', 'stock', 'balance'],
#  ['impeachment', 'climate', 'trial', 'norway'],
#  ['turkey', 'ankara', 'satterfield', 'turkish'],
#  ['mongolia', 'cent', 'socioeconomic', 'recovery'],
#  ['abortion', 'unfpa', 'abortions', 'partnerships'],
#  ['iran', 'iranian', 'claimed', 'china'],
#  ['mn', 'grandchildren', 'survived', 'preceded'],
#  ['africa', 'continent', 'cases', 'gabon'],
#  ['guterres', 'dujarric', 'ceasefires', 'guerrillas'],
#  ['commonwealth', 'rwanda', 'economies', 'coordinated'],
#  ['zaandam', 'burke', 'ship', 'passengers'],
#  ['g20', '20', 'civil', 'society'],
#  ['3m', 'trump', 'retaliation', 'defense'],
#  ['africa', 'moeti', 'kenya', 'fence'],
#  ['camps', 'camp', 'ips', 'refugees'],
#  ['sahel', 'laerke', 'agencies', 'million'],
#  ['rental', 'affordability', 'housing', 'rent'],
#  ['asia', 'children', 'south', 'unicef'],
#  ['said', 'cases', 'florida', 'saturday'],
#  ['mr', 'said', 'thursday', 'graduation'],
#  ['venezuela', 'maduro', 'didnt', 'outages'],
#  ['lebanon', 'explosion', 'beirut', 'lebanese'],
#  ['fashion', 'climate', 'microwave', 'schmitt'],
#  ['3m', 'direct', 'relief', 'providers'],
#  ['mr', 'said', 'new', 'graduation'],
#  ['newsweek', 'china', 'russia', 'official'],
#  ['prioritise', 'conflict', 'lives', 'ethical'],
#  ['coronavirus', 'schmitt', 'state', 'deaths'],
#  ['venezuelan', 'venezuelans', 'venezuelas', 'venezuela'],
#  ['iran', 'news', 'device', 'chemical'],
#  ['vegas', 'las', 'nevada', 'donation'],
#  ['korea', 'north', 'kaesong', 'koreas'],
#  ['russia', 'visas', 'chinese', 'china'],
#  ['people', 'mozambique', 'mekong', 'water'],
#  ['abe', 'thursday', 'save', 'zealand'],
#  ['venezuela', 'caracas', 'tons', 'shipment'],
#  ['kerala', 'state', 'precautionary', 'disruptive'],
#  ['tnh', 'aid', 'victims', 'samoa'],
#  ['yemen', 'aid', 'lowcock', 'email'],
#  ['heres', 'mr', 'gunman', 'snow'],
#  ['think', 'camerota', 'berman', 'going'],
#  ['african', 'africa', 'continent', 'economies'],
#  ['guaidó', 'maduro', 'opposition', 'lawmakers'],
#  ['rohingya', 'boat', 'refugees', 'malaysia'],
#  ['uruguayan', 'uruguay', 'passengers', 'montevideo'],
#  ['bangladesh', 'cyclone', 'amphan', 'storm'],
#  ['jonathan', 'tom', 'market', 'lisa'],
#  ['camerota', 'bottoms', 'kids', 'going'],
#  ['polish', 'baldwin', 'sheriff', 'coronavirus'],
#  ['gates', 'gavi', 'vaccines', 'vaccine'],
#  ['maduro', 'indictments', 'venezuelan', 'opposition'],
#  ['romaine', 'caroline', 'market', 'nasdaq'],
#  ['masks', '3m', 'says', 'usmade'],
#  ['nexus', 'peacebuilding', 'peace', 'triple'],
#  ['somalia', 'mogadishu', 'mohamed', 'ali'],
#  ['sanctions', 'putin', '26', 'washington'],
#  ['iran', 'biden', 'iranian', 'tehran'],
#  ['disasters', 'environment', 'diaries', 'drought'],
#  ['venezuela', 'maduro', 'landaeta', 'ramsey'],
#  ['andrés', 'food', 'says', 'kitchen'],
#  ['easter', 'pope', 'sunday', 'message'],
#  ['inglesby', 'practices', 'distancing', 'trump'],
#  ['judy', 'beasley', 'woodruff', 'david'],
#  ['masoumeh', 'trenches', 'dug', 'cemetery'],
#  ['council', 'resolution', 'conflicts', 'ceasefires'],
#  ['zaandam', 'passengers', 'broward', 'ship'],
#  ['direct', 'icu', 'relief', 'reliefs'],
#  ['neighborhoods', 'latino', 'undocumented', 'communities'],
#  ['___', 'wednesday', 'county', 'pm'],
#  ['merkel', 'conte', 'solidarity', 'eu'],
#  ['jenkins', 'sports', '19', 'novel'],
#  ['yamiche', 'judy', 'alcindor', 'woodruff'],
#  ['sanctions', 'ambassadors', 'countries', 'phenomena'],
#  ['hate', 'guterres', 'promote', 'enemy'],
#  ['afghan', 'pakistan', 'afghanistan', 'border'],
#  ['act', 'aids', 'gay', 'row'],
#  ['margaret', 'brennan', 'biden', 'sure'],
#  ['asylum', 'seekers', 'canada', 'status'],
#  ['paho', 'funding', 'maduro', 'venezuelans'],
#  ['italy', 'salvini', 'undocumented', 'migrants'],
#  ['older', 'guterres', 'report', '80'],
#  ['meals', 'salvation', 'food', 'hollander'],
#  ['lobbying', 'hired', 'firm', 'japan'],
#  ['gaza', 'yemen', 'cases', 'egypt'],
#  ['abbott', 'texas', 'authority', 'county'],
#  ['leadership', 'g20', 'heusgen', 'guterres'],
#  ['passengers', 'rotterdam', 'ships', 'zaandam'],
#  ['canada', '3m', 'ontario', 'masks'],
#  ['kemp', 'said', 'trump', 'coronavirus'],
#  ['___', 'memphis', 'thursday', 'wear'],
#  ['tb', 'diseases', 'biot', 'polio'],
#  ['africa', 'moeti', 'kenya', 'mauritania'],
#  ['china', 'xi', 'serbia', 'said'],
#  ['ice', 'detention', 'velasquez', 'sponsors'],
#  ['immigration', 'asylum', 'visas', 'immigrants'],
#  ['question', 'trump', 'dont', 'think'],
#  ['flu', 'today', 'kong', 'hong'],
#  ['badge', 'reproductive', 'barsa', 'trump'],
#  ['palestinian', 'unrwa', 'israel', 'palestinians'],
#  ['cooper', 'anderson', 'testing', 'really'],
#  ['china', 'india', 'lockdown', 'imported'],
#  ['cases', 'south', 'deaths', 'new'],
#  ['sinaloa', 'mountains', 'violence', 'lópez'],
#  ['africa', 'south', 'africans', 'ramaphosa'],
#  ['china', 'ppe', '3m', 'honeywell'],
#  ['taliban', 'khalilzad', 'frerichs', 'afghanistan'],
#  ['putin', 'ortagus', 'russia', 'g20'],
#  ['detainees', 'ice', 'irwin', 'detention'],
#  ['melvin', 'craig', 'harry', 'meghan'],
#  ['north', 'korea', 'pyongyang', 'kim'],
#  ['humanitarianism', 'explore', 'genocide', 'crises'],
#  ['says', 'lockdown', 'deaths', 'coronavirus'],
#  ['yemeni', 'saudi', 'houthis', 'advertisement'],
#  ['hurricane', 'season', 'fema', 'storms'],
#  ['yemen', 'hadramawt', 'alshahr', 'friday'],
#  ['hsbc', 'crimes', 'rakhine', 'burundi'],
#  ['eu', 'bloc', 'brussels', 'italy'],
#  ['appeal', 'guterres', 'secretarygeneral', 'developing'],
#  ['amphan', 'bangladesh', 'cyclone', 'shelters'],
#  ['provinces', 'alhamran', 'bayda', 'commander'],
#  ['comfort', 'navy', 'ship', 'hospital'],
#  ['putin', 'russia', 'discussed', 'referencing'],
#  ['iran', 'gaza', 'suspended', 'shrine'],
#  ['russian', 'russia', 'moscows', 'moscow'],
#  ['francine', 'tom', 'sergio', 'manus'],
#  ['billion', 'syria', 'syrian', 'pledged'],
#  ['immigration', 'immigrants', 'abc', 'citizenship'],
#  ['donetsk', 'luhansk', 'ukraine', 'ukrainian'],
#  ['brooklyn', 'adams', 'borough', 'eric'],
#  ['___', 'new', 'said', 'jetblue'],
#  ['award', 'athletes', 'cruz', 'rapinoe'],
#  ['venezuela', 'guaidó', 'maduro', 'sanctions'],
#  ['payne', 'australia', 'yang', 'yangs'],
#  ['virus', 'tariff', 'uk', 'cnn'],
#  ['singapore', 'dormitories', 'workers', 'migrant'],
#  ['subsaharan', 'food', 'climate', 'africa'],
#  ['lebanon', 'lockdown', 'restrictions', 'africa'],
#  ['fao', 'yemen', 'food', 'ahmed'],
#  ['hayes', 'right', 'thats', 'think'],
#  ['russia', 'putin', 'ortagus', 'g20'],
#  ['faith', 'file', 'multibilliondollar', 'smith'],
#  ['bangladesh', 'flooding', 'affected', 'districts'],
#  ['blackwell', 'voiceover', 'paul', 'moos'],
#  ['massachusetts', 'stayathome', 'advisory', 'boston'],
#  ['feroz', 'hospital', 'dr', 'provinces'],
#  ['myanmar', 'kachin', 'idp', 'camp'],
#  ['yemen', 'hadramawt', 'alshahr', 'friday'],
#  ['conference', 'syria', 'billion', 'syrias'],
#  ['link', 'thursday', 'said', 'coronavirus'],
#  ['thai', 'ship', 'docking', 'cruise'],
#  ['bogotá', 'venezuelans', 'colombian', 'migrants'],
#  ['vause', 'biden', 'taliban', 'sanders'],
#  ['mn', 'grandchildren', 'survived', 'preceded'],
#  ['anderson', 'becky', 'impeachment', 'malveaux'],
#  ['carlson', '3m', 'fauci', 'tucker'],
#  ['billion', 'syria', 'syrian', 'pledged'],
#  ['hemmer', 'oz', 'tonight', 'good'],
#  ['yemen', 'grande', 'restrictions', 'country'],
#  ['cruise', 'passengers', 'canal', 'zaandam'],
#  ['italy', 'italian', 'tnh', 'lombardy'],
#  ['holmes', 'stout', 'turkey', 'yes'],
#  ['polish', 'medicaid', 'enrollment', 'unemployment'],
#  ['says', 'deaths', 'puerto', 'crozier'],
#  ['sailing', 'sailors', 'maldives', 'boats'],
#  ['palestinian', 'israel', 'hamas', 'palestinians'],
#  ['burkina', 'faso', 'jihadists', 'du'],
#  ['sao', 'paulo', 'colombians', 'colombia'],
#  ['wfp', 'beasley', 'people', 'million'],
#  ['migrant', 'migrants', 'breitbartlondon', 'boats'],
#  ['staged', 'venezuelas', 'sharing', 'venezuelan'],
#  ['taliban', 'sigar', 'afghanistan', 'afghan'],
#  ['sex', 'women', 'trials', 'data'],
#  ['afloat', 'african', 'societies', 'imf'],
#  ['hemmati', 'iran', 'banks', 'korea'],
#  ['beijing', 'china', 'payback', 'trump'],
#  ['canada', 'premier', 'trudeau', 'newfoundland'],
#  ['lowcock', 'said', 'appeal', 'guterres'],
#  ['library', 'yorkpresbyterian', 'berisha', 'patient'],
#  ['wha', 'token', 'abdication', 'xi'],
#  ['___', 'chicago', 'new', 'india'],
#  ['usaid', 'assistance', 'foreign', 'important'],
#  ['stc', 'riyadh', 'yemen', 'coalition'],
#  ['girls', 'education', 'unesco', 'science'],
#  ['virus', 'urged', 'sri', 'said'],
#  ['torture', 'detention', 'alfakih', 'disappearances'],
#  ['iran', 'iranian', 'sanctions', 'petrochemical'],
#  ['alkhadra', 'tripoli', 'easternbased', 'patients'],
#  ['kim', 'north', 'korean', 'korea'],
#  ['maduro', 'agreement', 'opposition', 'venezuela'],
#  ['kim', 'nk', 'north', 'regime'],
#  ['gates', 'moon', 'korea', 'foundation'],
#  ['leonardo', 'drs', 'cross', 'red'],
#  ['premise', 'data', 'contributors', 'trustworthy'],
#  ['venezuelan', 'venezuelans', 'venezuela', 'migrants'],
#  ['fda', 'tests', 'eua', 'injection'],
#  ['secretariat', 'staffers', 'telecommuting', 'work'],
#  ['shelter', 'cathedral', 'francisco', 'colfax'],
#  ['sanaa', 'yemen', 'staff', 'addis'],
#  ['quest', 'foroohar', 'going', 'richard'],
#  ['survivors', 'indonesia', 'easter', 'iran'],
#  ['iran', 'msf', 'sanctions', 'isfahan'],
#  ['hayes', 'know', 'like', 'theyre'],
#  ['kurdish', 'cnn', 'church', 'tiktok'],
#  ['medicines', 'vaccine', 'trials', 'think'],
#  ['kabul', 'afghanistan', 'taliban', 'afghan'],
#  ['gaza', 'wednesday', 'israel', 'palestinian'],
#  ['california', 'angeles', 'los', 'san'],
#  ['gaza', 'yemen', 'cases', 'iran'],
#  ['file', 'resolution', 'conflicts', 'council'],
#  ['tb', 'diseases', 'biot', 'polio'],
#  ['trump', 'sunday', 'fauci', 'cnn'],
#  ['yemen', 'ksrelief', 'saudi', 'arabia'],
#  ['wright', 'miliband', 'camp', 'rohingya'],
#  ['palestinian', 'israel', 'israeli', 'bank'],
#  ['prison', 'cuomo', 'clemency', 'gov'],
#  ['south', 'africa', 'cape', 'countries'],
#  ['production', 'oil', 'hawley', 'protected'],
#  ['g20', 'leaders', 'saudi', 'summit'],
#  ['limits', 'enacted', 'gatherings', 'states'],
#  ['disinformation', 'russia', 'russian', 'kremlin'],
#  ['kim', 'trump', 'north', 'korea'],
#  ['borrell', 'council', 'foreign', 'heiko'],
#  ['data', 'venezuela', 'information', 'organisations'],
#  ['zaandam', 'huergo', 'ships', 'holland'],
#  ['immigration', 'trump', 'china', 'border'],
#  ['brazil', 'argentina', 'brazilian', 'argentine'],
#  ['detainees', 'ice', 'adelanto', 'mesa'],
#  ['venezuelans', 'peru', 'venezuela', 'colombia'],
#  ['kobach', 'border', 'illegally', 'entry'],
#  ['cnn', 'people', 'ripley', 'singapore'],
#  ['anderson', 'bloomberg', 'schechter', 'scouts'],
#  ['iran', 'cyber', 'gilead', 'cybersecurity'],
#  ['vause', 'cnn', 'voiceover', 'amanpour'],
#  ['project', 'exploration', 'royalty', 'majestic'],
#  ['camp', 'kenya', 'refugees', 'refugee'],
#  ['gorani', 'hala', 'clip', 'video'],
#  ['hayes', 'know', 'thats', 'just'],
#  ['ice', 'detainees', 'garcia', 'caucus'],
#  ['cent', 'education', 'ecw', 'children'],
#  ['ice', 'deportees', 'detainees', 'detention'],
#  ['masks', 'n95', 'fema', 'morain'],
#  ['vaccine', 'vaccines', 'h5n1', 'flu'],
#  ['stimulus', 'international', 'security', 'administration'],
#  ['blackwell', 'paul', 'cnn', 'christi'],
#  ['older', 'report', 'aged', 'guterres'],
#  ['deliberate', 'kabul', 'afghanistan', 'afghan'],
#  ['taiwan', 'taiwanese', 'solomon', 'taipei'],
#  ['dose', 'ethical', 'promising', 'research'],
#  ['usaid', 'programs', 'aid', 'foreign'],
#  ['congo', 'displaced', 'dr', 'people'],
#  ['imf', 'maduro', 'venezuela', 'financing'],
#  ['exercises', 'philippine', 'mosques', 'enforcing'],
#  ['melber', 'kristol', 'ari', 'jeffries'],
#  ['yemen', 'hadramawt', 'alshahr', 'dengue'],
#  ['billion', 'aid', 'grants', 'spending'],
#  ['melber', 'going', 'ari', 'think'],
#  ['direct', 'oxygen', 'yemen', 'concentrators'],
#  ['development', 'covid19', 'undp', 'crisis'],
#  ['desantis', 'ships', 'florida', 'floridians'],
#  ['border', 'migrants', 'immigration', 'expelled'],
#  ['sharpton', 'reverend', 'thank', 'dont'],
#  ['market', 'systems', 'wounds', 'players'],
#  ['yaroshenko', 'russia', 'moscow', 'prison'],
#  ['aid', 'funding', 'generosity', 'administration'],
#  ['food', 'beasley', 'syria', 'vulnerable'],
#  ['canada', 'premier', 'trudeau', 'newfoundland'],
#  ['zones', 'surgery', 'operating', 'war'],
#  ['burnett', 'going', 'president', 'people'],
#  ['jilin', 'heres', 'funeral', 'moguls'],
#  ['cyclone', 'storms', 'amphan', 'bangladesh'],
#  ['baker', 'avoided', 'click', 'massachusetts'],
#  ['cruise', 'new', 'bars', 'barcelona'],
#  ['cross', 'red', 'donations', 'party'],
#  ['ventilator', 'dreamers', 'afghan', 'mit'],
#  ['irans', 'ali', 'iran', 'jahanshahi'],
#  ['israel', 'communications', 'flight', 'spying'],
#  ['council', 'lowcock', 'syria', 'ambassador'],
#  ['iran', 'irans', 'sanctions', 'iranian'],
#  ['news', 'porn', 'facade', 'breonna'],
#  ['tripoli', 'alkhadra', 'libya', 'salim'],
#  ['countries', 'health', 'organization', 'directed'],
#  ['indicators', 'fsi', 'messner', 'fragility'],
#  ['curnow', 'black', 'floyd', 'cnn'],
#  ['food', 'crops', 'supply', 'local'],
#  ['people', 'heres', 'dont', 'marriages'],
#  ['lemon', 'don', 'cnn', 'kim'],
#  ['brazil', 'argentina', 'brazilian', 'argentine'],
#  ['beasley', 'hunger', 'food', 'million'],
#  ['payroll', 'taxes', 'congress', 'contained'],
#  ['remittances', 'yemens', 'mohammed', 'yemeni'],
#  ['displaced', 'norwegian', 'displacement', 'violence'],
#  ['seafarers', 'crews', 'crew', 'shipping'],
#  ['migrants', 'asylum', 'shelters', 'mexico'],
#  ['guam', 'rico', 'puerto', 'states'],
#  ['ice', 'immigrants', 'detainees', 'detention'],
#  ['yemen', 'cases', 'gaza', 'iran'],
#  ['ndayishimiye', 'nkurunziza', 'burundi', 'hardliners'],
#  ['mr', 'trump', 'xi', 'letter'],
#  ['perth', 'ship', 'crew', 'sydney'],
#  ['hayes', 'know', 'youre', 'thats'],
#  ['ice', 'immigration', 'enforcement', 'administration'],
#  ['said', 'mr', 'nursing', 'thursday'],
#  ['barsa', 'reproductive', 'abortion', 'abortions'],
#  ['memo', 'usaid', 'gear', 'supplies'],
#  ['sanctions', 'policy', 'tool', 'economic'],
#  ['lagos', 'mr', 'garment', 'mexican'],
#  ['vause', 'clip', 'video', 'remdesivir'],
#  ['climate', 'resettlement', 'migrants', 'refugee'],
#  ['beasley', 'famines', 'biblical', 'proportions'],
#  ['children', 'malnourished', 'food', 'malnutrition'],
#  ['sanctions', 'iran', 'irans', 'american'],
#  ['juba', 'sudan', 'sudanese', 'south'],
#  ['au', 'eu', 'tech', 'carbon'],
#  ['palestinian', 'israel', 'gaza', 'hamas'],
#  ['cambodia', 'westerdam', 'sihanoukville', 'passengers'],
#  ['shop', 'donated', 'retailer', 'donate'],
#  ['china', 'chinas', 'neighbors', 'charm'],
#  ['maduro', 'venezuela', 'iran', 'venezuelas'],
#  ['appropriations', 'funding', 'senate', 'includes'],
#  ['yemen', 'yemens', 'lowcock', 'mr'],
#  ['chinese', 'russian', 'russia', 'moscow'],
#  ['ingraham', 'biden', 'obama', 'clip'],
#  ['yemen', 'coalition', 'houthi', 'civilians'],
#  ['amanpour', 'think', 'ortiz', 'isaacson'],
#  ['islands', 'uk', 'roberts', 'says'],
#  ['jarrett', 'romans', 'iowa', 'romney'],
#  ['drugs', 'researchers', 'vaccines', 'gilead'],
#  ['taliban', 'afghan', 'district', 'prisoners'],
#  ['tripoli', 'grad', 'hifter', 'man'],
#  ['holmes', 'cnn', 'ripley', 'know'],
#  ['raids', 'ice', 'mississippi', 'employers'],
#  ['pompeo', 'administration', 'abdullah', 'crown'],
#  ['china', 'sea', 'chinese', 'chinas'],
#  ['ecw', 'learning', 'education', 'furthest'],
#  ['programs', 'yemen', 'laerke', 'ocha'],
#  ['black', 'new', 'sunday', 'protests'],
#  ['furlough', 'pompeo', 'iran', 'prisoner'],
#  ['crossing', 'yarubiyah', 'crossborder', 'deliveries'],
#  ['canada', 'doctors', 'completed', 'shes'],
#  ['andrés', 'chef', 'meals', 'kitchen'],
#  ['iran', 'proxies', 'iranian', 'mullahs'],
#  ['pakistan', 'aid', 'pakistans', 'groups'],
#  ['curnow', 'blast', 'beirut', 'robyn'],
#  ['locusts', 'infestation', 'insects', 'swarm'],
#  ['ngos', 'response', 'communities', 'flexible'],
#  ['percent', 'friday', 'investors', 'dow'],
#  ['curnow', 'beirut', 'know', 'nassif'],
#  ['holmes', 'bezos', 'ripley', 'cnn'],
#  ['iran', 'khamenei', 'strange', 'sanctions'],
#  ['labor', 'child', 'boys', 'children'],
#  ['migrants', 'libya', 'mexico', 'sea'],
#  ['mexico', 'lujan', 'grisham', 'new'],
#  ['zaandam', 'ship', 'holland', 'bulletin'],
#  ['immigration', 'clients', 'detention', 'detainees'],
#  ['gorani', 'harris', 'biden', 'kamala'],
#  ['maccallum', 'going', 'adams', 'know'],
#  ['dormitories', 'singapore', 'migrant', 'workers'],
#  ['lowcock', 'countries', 'boomerang', 'rich'],
#  ['ofer', 'aclu', 'jails', 'prisons'],
#  ['kinkade', 'voiceover', 'unidentified', 'female'],
#  ['barsa', 'abortion', 'reproductive', 'sexual'],
#  ['venezuelans', 'venezuela', 'peru', 'colombia'],
#  ['citgo', 'foundation', 'bolívar', 'venezuela'],
#  ['anderson', 'becky', 'liverpool', 'clip'],
#  ['iranian', 'regime', 'irans', 'iran'],
#  ['cyclone', 'bangladesh', 'storm', 'india'],
#  ['food', 'mr', 'says', 'beasley'],
#  ['kilometers', 'deaths', 'reported', 'martial'],
#  ['procurement', 'ukraine', 'said', 'company'],
#  ['yemen', 'aid', 'houthis', 'uae'],
#  ['widodo', 'ghosts', 'indonesia', 'reuters'],
#  ['passengers', 'cambodia', 'ship', 'sihanoukville'],
#  ['guterres', 'guerrillas', 'file', 'dujarric'],
#  ['resolution', 'council', 'file', 'draft'],
#  ['chinese', 'china', 'session', 'virus'],
#  ['regime', 'iran', 'ncri', 'iranian'],
#  ['penn', 'blitzer', 'josh', 'term'],
#  ['refugees', 'asylum', 'seekers', 'moria'],
#  ['venezuela', 'maduro', 'maduros', 'regime'],
#  ['ive', 'childbirth', 'dying', 'trump'],
#  ['matamoros', 'mexico', 'migrants', 'undocumented'],
#  ['india', 'forest', 'fires', 'indian'],
#  ['wet', 'animals', 'markets', 'wildlife'],
#  ['venezuela', 'maduros', 'maduro', 'venezuelas'],
#  ['ventilators', 'medtronic', 'massachusetts', 'ventilator'],
#  ['alight', 'pakistan', 'wwwwearealightorg', 'education'],
#  ['tb', 'diseases', 'biot', 'polio'],
#  ['forum', 'riyadh', 'humanitarian', 'rabeeah'],
#  ['plastic', 'waste', 'nepal', 'garbage'],
#  ['dengue', 'mosquitoes', 'bolivia', 'climate'],
#  ['solar', 'energy', 'footprint', 'power'],
#  ['reporter', 'heres', 'covering', 'schwartz'],
#  ['syria', 'assad', 'syrian', 'regime'],
#  ['cyclone', 'amphan', 'storm', 'landfall'],
#  ['china', 'mr', 'xi', 'assembly'],
#  ['countries', 'global', 'bloom', 'worlds'],
#  ['schumer', 'tuesday', 'authorizations', 'fauci'],
#  ['bolsonaro', 'mr', 'brazil', 'mexico'],
#  ['resolution', 'council', 'draft', 'secretarygenerals'],
#  ['africa', 'religious', 'communities', 'subsaharan'],
#  ['mother', 'father', 'tokyo', 'bedside'],
#  ['said', 'state', 'gov', 'photo'],
#  ['visas', 'russia', 'russias', 'china'],
#  ['joel', 'asylum', 'ari', 'shapiro'],
#  ['iran', 'iranian', 'iraq', 'kabul'],
#  ['audiences', 'journalism', 'membership', 'readers'],
#  ['korea', 'north', 'pyongyang', 'entering'],
#  ['vaccine', 'gates', 'gavi', 'vaccines'],
#  ['gabaroni', 'zaandam', 'passengers', 'florida'],
#  ['___', 'said', 'tuesday', 'texas'],
#  ['judy', 'woodruff', 'marcia', 'biggs'],
#  ['guaidó', 'opposition', 'lawmakers', 'venezuelan'],
#  ['uae', 'arabia', 'saudi', 'yemen'],
#  ['discount', 'error', 'cartoon', 'unemployment'],
#  ['saudi', 'yemen', 'houthi', 'ebb'],
#  ['locust', 'locusts', 'swarms', 'insects'],
#  ['gaza', 'hamas', 'quarantine', 'wedding'],
#  ['li', 'wuhan', 'freedom', 'speech'],
#  ['___', 'sunday', 'cases', 'kong'],
#  ['navarro', 'mr', '3m', 'multinational'],
#  ['inspector', 'navarro', 'general', 'trump'],
#  ['smith', 'rapinoe', 'athletes', 'sports'],
#  ['yemen', 'houthis', 'aid', 'programs'],
#  ['aid', 'yemen', 'rebels', 'programs'],
#  ['xi', 'chinese', 'china', 'successful'],
#  ['msf', 'isfahan', 'iran', 'rouhani'],
#  ['alkhadra', 'facility', 'tripoli', 'patients'],
#  ['friday', 'school', 'cases', 'new'],
#  ['iran', 'monday', 'milan', 'said'],
#  ['usns', 'comfort', 'york', 'ship'],
#  ['chikungunya', 'kenya', 'cholera', 'outbreaks'],
#  ['melber', 'ari', 'ruiz', 'christie'],
#  ['ewing', 'basketball', 'mens', 'season'],
#  ['sikhs', 'united', 'hotline', 'registered'],
#  ['egeland', 'horrific', 'sanctions', 'blanket'],
#  ['dujarric', 'happiness', 'unhappy', 'swarms'],
#  ['baldwin', 'think', 'johnson', 'im'],
#  ['yemen', 'houthis', 'aid', 'programs'],
#  ['council', 'security', 'courageous', 'resolution'],
#  ['protests', 'police', 'ecuador', 'abuses'],
#  ['news', 'black', 'parents', 'americas'],
#  ['border', 'migrants', 'mexican', 'cbp'],
#  ['livingston', 'bread', 'hunger', 'music'],
#  ['china', 'accuse', 'trump', 'states'],
#  ['ive', 'childbirth', 'dying', 'trump'],
#  ['hua', 'chinese', 'immoral', 'china'],
#  ['incarcerated', 'correctional', 'categories', 'marion'],
#  ['florida', 'dewine', 'cases', 'michigan'],
#  ['israel', 'palestinian', 'pa', 'gaza'],
#  ['gaza', 'hamas', 'quarantine', 'wedding'],
#  ['iata', 'airlines', 'revenue', 'middle'],
#  ['theater', 'ballet', 'mitchell', 'theaters'],
#  ['amanpour', 'isaacson', 'know', 'gates'],
#  ['kaye', 'going', 'berman', 'hotez'],
#  ['prisoners', 'inmates', 'prison', 'brazil'],
#  ['education', 'psychosocial', 'quality', 'learning'],
#  ['iran', 'mullahs', 'regime', 'rouhani'],
#  ['camp', 'women', 'violence', 'sudan'],
#  ['republicans', 'measure', 'rep', 'democrats'],
#  ['startups', 'marketing', 'runway', 'pr'],
#  ['eu', 'russian', 'sanctions', 'rferl'],
#  ['council', 'resolution', 'tunisia', 'resolutions'],
#  ['tunisian', 'tunisia', 'migrants', 'italy'],
#  ['resolution', 'council', 'security', 'teeth'],
#  ['newark', 'airlines', 'flights', 'employees'],
#  ['kim', 'korea', 'north', 'korean'],
#  ['___', 'japan', 'cases', 'friday'],
#  ['indias', 'migrants', 'workers', 'rajasthan'],
#  ['maryland', 'hogan', 'landed', 'dulles'],
#  ['patriots', 'foster', 'convention', 'vineyard'],
#  ['ice', 'deportees', 'detainees', 'deported'],
#  ['___', 'seating', 'blasio', 'cases'],
#  ['oil', 'libya', 'easternbased', 'libyas'],
#  ['tapper', 'watt', 'jake', 'collins'],
#  ['cases', 'saturday', 'advertisement', 'gallego'],
#  ['lowcock', 'yemen', 'cliff', 'said'],
#  ['michele', 'pompeo', 'miller', 'soundbite'],
#  ['cambodian', 'hun', 'passengers', 'cambodia'],
#  ['bahamas', 'ship', 'passengers', 'cruise'],
#  ['patients', 'hotel', 'staff', 'center'],
#  ['brunhuber', 'clip', 'cnn', 'video'],
#  ['guaido', 'venezuelan', 'opposition', 'lawmakers'],
#  ['curnow', 'just', 'cnn', 'know'],
#  ['state', 'said', 'school', 'county'],
#  ['wrights', 'wright', 'october', 'henry'],
#  ['nobilo', 'bloomberg', 'bianca', 'burns'],
#  ['guterres', 'dujarric', 'ceasefires', 'guerrillas'],
#  ['yemen', 'wfp', 'yemeni', 'aid'],
#  ['lebanon', 'explosion', 'nonprofit', 'beirut'],
#  ['africa', 'usaid', 'assistance', 'ventilators'],
#  ['yemen', 'separatists', 'southern', 'ceasefire'],
#  ['lebanon', 'restrictions', 'lockdown', 'africa'],
#  ['quake', 'earthquake', 'planners', 'earthquakes'],
#  ['sanctions', 'imf', 'iran', 'block'],
#  ['rico', 'peru', 'americans', 'wondered'],
#  ['ecw', 'allocated', 'education', 'grantees'],
#  ['imf', 'ukraine', 'arrangement', 'rferl'],
#  ['anderson', 'becky', 'dam', 'cnn'],
#  ['irc', 'yemen', 'fighting', 'selfrule'],
#  ['cubans', 'cuban', 'island', 'tourists'],
#  ['gaza', 'schools', 'gazas', 'students'],
#  ['venezuelas', 'imf', 'venezuela', 'financing'],
#  ['marib', 'yemen', 'houthis', 'province'],
#  ['zimbabwe', 'zimbabweans', 'zimbabwes', 'zimbabwean'],
#  ['coronavirus', 'friday', 'trump', 'white'],
#  ['storm', 'cyclone', 'shelters', 'indian'],
#  ['cubic', 'daoudi', 'wfp', '132'],
#  ['sanjay', 'cooper', 'gupta', 'anderson'],
#  ['coronavirus', 'salon', 'thursday', 'reopening'],
#  ['brunhuber', 'know', 'damon', 'schools'],
#  ['ap', 'venezuela', 'feb', 'caracas'],
#  ['county', 'texas', 'dakota', 'maddow'],
#  ['port', 'hezbollah', 'nitrate', 'ammonium'],
#  ['___', 'speedway', 'tuesday', 'health'],
#  ['congo', 'ebola', 'case', 'outbreak'],
#  ['travel', 'china', 'ban', 'frieden'],
#  ['yemens', 'saudiled', 'rebels', 'recognized'],
#  ['leaders', 'global', 'g20', 'clock'],
#  ['taiwan', 'taiwanese', 'taiwans', 'tsai'],
#  ['holland', 'zaandam', 'guests', 'disembarkation'],
#  ['saudi', 'yemen', 'separatists', 'arabia'],
#  ['becky', 'anderson', 'know', 'going'],
#  ['charities', 'relief', 'haiti', 'supplies'],
#  ['parties', 'conflicts', 'envoys', 'appeal'],
#  ['yemens', 'msf', 'yemen', 'doctors'],
#  ['north', 'korea', 'shortrange', 'korean'],
#  ['maduro', 'venezuela', 'venezuelan', 'caracas'],
#  ['vehicle', 'vehicles', 'coxs', 'camps'],
#  ['reagents', 'countries', 'chemical', 'manufacturers'],
#  ['mr', 'said', 'trump', 'thursday'],
#  ['cyprus', 'tourism', 'vacationers', 'flights'],
#  ['collins', 'faith', 'science', 'people'],
#  ['holmes', 'michael', 'lemmon', 'turkey'],
#  ['guterres', 'videoconference', 'package', 'click'],
#  ['antibody', 'tests', 'swab', 'physicians'],
#  ['breakup', 'closeness', 'ex', 'want'],
#  ['louvre', 'italy', 'museum', 'visitors'],
#  ['allen', 'natalie', 'people', 'jasarevic'],
#  ['sanctions', 'iran', 'venezuela', 'maduro'],
#  ['iran', 'offices', 'saturday', 'tehran'],
#  ['coronavirus', 'usa', 'york', 'vote'],
#  ['mr', 'sanctions', 'american', 'iran'],
#  ['mr', 'maduro', 'maduros', 'venezuelas'],
#  ['china', 'chinese', 'masks', 'ma'],
#  ['funding', 'aid', 'billion', 'spending'],
#  ['korean', 'pyongyang', 'kim', 'north'],
#  ['kim', 'kims', 'weapons', 'jong'],
#  ['court', 'hawaii', 'bar', 'justice'],
#  ['peacekeeping', 'capacities', 'clarke', 'cooper'],
#  ['regan', 'boston', 'eulogy', 'donna'],
#  ['tuesday', 'antibody', 'authorizations', 'fauci'],
#  ['afloat', 'african', 'societies', 'fund'],
#  ['bishops', 'worship', 'church', 'catholic'],
#  ['darfur', 'measles', 'countries', 'europeans'],
#  ['iran', 'mr', 'tehran', 'qom'],
#  ['education', 'denmark', 'girls', 'ecw'],
#  ['cuomo', 'sellers', 'bernie', 'walsh'],
#  ['contact', 'county', 'contacttracing', 'contacts'],
#  ['rohingya', 'boats', 'malaysia', 'bangladesh'],
#  ['north', 'korea', 'koreas', 'kim'],
#  ['vause', 'remdesivir', 'cnn', 'moos'],
#  ['kim', 'kims', 'weapons', 'jong'],
#  ['jeff', 'duncan', 'reid', 'paula'],
#  ['judy', 'woodruff', 'biden', 'stu'],
#  ['friend', 'im', 'ozarks', 'chances'],
#  ['fashion', 'textile', 'sourcing', 'chain'],
#  ['artemisinin', 'forwardlooking', 'clinical', 'ot101'],
#  ['thai', 'insurgents', 'peace', 'thailands'],
#  ['blitzer', 'wolf', 'right', 'people'],
#  ['canoe', 'lagos', 'fish', 'canoes'],
#  ['hospital', 'javits', 'park', 'monday'],
#  ['food', 'insects', 'farmers', 'africa'],
#  ['caroline', 'romaine', 'market', 'stocks'],
#  ['north', 'korea', 'koreas', 'missiles'],
#  ['india', 'strategic', 'lac', 'indian'],
#  ['li', 'wuhan', 'freedom', 'speech'],
#  ['kenya', '___', 'africa', 'alcohol'],
#  ['beasley', 'wfp', 'sudan', 'food'],
#  ['trump', 'regulatory', 'environmental', 'epa'],
#  ['todd', 'bernie', 'think', 'sanders'],
#  ['st', 'spring', 'game', 'john'],
#  ['chaiban', 'children', 'unicef', 'yemen'],
#  ['anderson', 'huawei', 'clip', 'china'],
#  ['sharpton', 'black', 'bass', 'lumumba'],
#  ['southeast', 'brief', 'region', 'asia'],
#  ['pg', 'red', 'crescent', 'ifrc'],
#  ['masks', 'n95', 'fema', 'morain'],
#  ['kinkade', 'lynda', 'moos', 'sanders'],
#  ['truce', 'southern', 'yemen', 'arab'],
#  ['navajo', 'mexico', 'richardson', 'new'],
#  ['parties', 'conflicts', 'envoys', 'appeal'],
#  ['bishops', 'worship', 'church', 'catholic'],
#  ['ice', 'detention', 'velasquez', 'migrants'],
#  ['mail', 'packages', 'fedex', 'shipments'],
#  ...]

# %% [markdown]
# ## For all blocks
#
# Running the same analysis for all blocks of countries.

# %%
# Declare global variables

gulfCountries = ['AE', 'KW', 'QA', 'SA']
eaCountries = ['US', 'UK', 'DE', 'FR']
ngmpCountries = ['CN', 'RU', 'IR', 'TR']
interestingKeywords = ['human', 'humanitarian', 'humanitarianism', 'humane', 'donation', 'donations', 'donate',
                       'donated', 'donating', 'aid', 'support', 'medical', 'food', 'supply', 'help', 'helped',
                       'cooperation', 'relief', 'fund']

# %%
# Run the script for Gulf countries

for country in gulfCountries:
    print('\n\nProcessing',country,'...\n')
    dfCountry = df[df['country']==country] # Get the df for the country
    arr = dfCountry["text"].to_numpy() # Get the text as array
    corpus = arr.tolist() # Convert to list
    corpusLen = len(corpus) # Get length of list
    trainingLen = corpusLen * 0.2 # Train it on 20% of the text items
    trainingLen = int(trainingLen)
    trainArr = corpus[:trainingLen] # First 20% of corpus
    restArr = corpus[-(len(corpus)-trainingLen-4):] # Last 80% of corpus
    X = tfidf.fit_transform(trainArr) # Fit transform
    feature_names = np.array(tfidf.get_feature_names())
    responses = tfidf.transform(restArr) # TFIDF Transform
    resultsArr = [get_top_tf_idf_words(response,4) for response in responses]
    finalArr = [l.tolist() for l in resultsArr] # Final array output
    for item in finalArr: # Print the Results
        for subitem in item:
            if subitem in interestingKeywords:
                print(item)
# Out:
# Processing AE ...
#
# ['labour', 'human', 'pakistanis', 'leave']
# ['yemen', 'food', 'decline', 'reverse']
# ['yemen', 'august', 'billion', 'aid']
# ['food', 'afp', 'world', 'programme']
# ['iran', 'sanctions', 'relief', 'spending']
# ['water', 'management', 'supply', 'region']
# ['meals', 'campaign', 'uae', 'donations']
# ['erc', 'fund', 'initiatives', 'cooperation']
# ['erc', 'fund', 'initiatives', 'cooperation']
# ['fund', 'community', 'dubai', 'society']
# ['metric', 'uae', 'tonnes', 'medical']
# ['aid', 'idlib', 'extension', 'mandate']
# ['mbrch', 'fund', 'melha', 'bu']
# ['donated', 'sector', 'community', 'intercoil']
# ['uae', 'cooperation', 'assisting', 'covid19']
# ['water', 'supply', 'region', 'mena']
# ['uae', 'aid', 'medical', 'evacuated']
# ['uae', 'aid', 'medical', 'evacuated']
# ['tallest', 'box', 'meals', 'donation']
# ['medical', 'aid', 'iraqi', 'iran']
# ['medical', 'aid', 'iraqi', 'iran']
# ['erc', 'food', 'segments', 'parcels']
# ['canadian', 'friendly', 'cooperation', 'abdullah']
# ['donation', 'million', 'dubai', 'charity']
# ['israel', 'israeli', 'cooperation', 'arab']
# ['uae', 'hashimy', 'uaes', 'cooperation']
# ['yemen', 'interference', 'aid', 'scale']
# ['kazakhstan', 'metric', 'medical', 'uae']
# ['palestine', 'ksrelief', 'saudi', 'relief']
# ['labourers', 'workers', 'labour', 'food']
# ['donate', 'relief', 'donation', 'educational']
# ['donate', 'relief', 'donation', 'educational']
# ['donate', 'relief', 'donation', 'educational']
# ['summit', 'g20', 'mohamed', 'cooperation']
# ['tonnes', 'uae', 'sent', 'medical']
# ['tonnes', 'uae', 'medical', 'aid']
# ['tonnes', 'uae', 'medical', 'aid']
# ['fund', 'sectors', 'charitable', 'community']
# ['meals', 'campaign', 'donations', 'million']
# ['fund', 'department', 'society', 'contribute']
# ['fraternity', 'human', 'god', 'committee']
# ['medical', 'aid', 'uae', 'training']
# ['medical', 'aid', 'uae', 'training']
# ['food', 'disruptions', 'chains', 'supply']
# ['food', 'disruptions', 'chains', 'supply']
# ['food', 'august', '15', 'disruptions']
# ['african', 'supplies', 'cargo', 'medical']
# ['sudan', 'foundation', 'khartoum', 'aid']
# ['meals', 'donations', 'campaign', 'million']
# ['donation', 'million', 'dubai', 'ber']
# ['states', 'supply', 'realities', 'uncertainty']
# ['russia', 'aid', 'syria', 'crossborder']
# ['brazilian', 'brazil', 'abdullah', 'cooperation']
# ['etihad', 'medical', 'dhabi', 'abu']
# ['fund', 'charitable', 'contribution', 'private']
# ['meals', 'food', 'haddad', 'campaign']
# ['meals', 'donations', 'maktoum', 'campaign']
# ['erc', 'ministry', 'education', 'fund']
# ['uae', 'dispatched', 'aid', 'tonnes']
# ['august', 'bus', 'food', 'winter']
# ['g20', 'meeting', 'cooperation', 'virtual']
# ['cooperation', 'republic', 'road', 'development']
# ['food', 'husain', 'syria', 'prices']
# ['medical', 'sent', 'professionals', 'tonnes']
# ['mohammed', 'helped', 'sheikh', 'thanked']
# ['meals', 'campaign', 'food', 'haddad']
# ['sector', 'fund', 'community', 'emirate']
# ['food', 'consumption', 'security', 'uae']
# ['meals', 'campaign', 'donations', 'million']
#
#
# Processing KW ...
#
# ['kuwait', 'indian', 'medical', 'hospitals']
# ['italy', 'epidemic', 'countries', 'help']
#
#
# Processing QA ...
#
# ['food', 'economies', 'wfp', 'beasley']
# ['charity', 'qatar', 'unicef', 'cooperation']
# ['blood', 'donation', 'donor', 'religion']
# ['yemen', 'food', 'wfp', 'million']
# ['yemen', 'aid', 'probability', 'shortfall']
# ['syria', 'syrians', 'pledges', 'food']
# ['economist', 'trillion', 'food', 'nations']
# ['distributed', 'baskets', 'charity', 'food']
# ['qc', 'food', 'distribution', 'charity']
# ['qatar', 'cooperation', 'research', 'partner']
# ['cooperation', 'china', 'international', 'community']
# ['vanuatu', 'cyclone', 'help', 'aid']
# ['vanuatu', 'cyclone', 'help', 'aid']
# ['ethiopia', 'food', 'sudan', 'region']
# ['g20', 'global', 'coordination', 'cooperation']
# ['wfp', 'food', 'category', 'acute']
# ['fund', 'cares', 'csr', 'donations']
# ['fund', 'cares', 'csr', 'donations']
# ['rights', 'human', 'visits', 'institutions']
# ['food', 'regional', 'plants', 'owns']
# ['baskets', 'distributed', 'food', 'beneficiaries']
# ['kumar', 'food', 'activists', 'india']
# ['qatar', 'tonnes', 'medical', 'delivered']
# ['baskets', 'food', 'project', 'distributed']
#
#
# Processing SA ...
#
# ['projects', 'yemen', 'support', 'saudi']
# ['beirut', 'lebanon', 'rescue', 'medical']
# ['syria', 'crossborder', 'uk', 'aid']
# ['rohingya', 'myanmar', 'human', 'bangladesh']
# ['crossing', 'mandate', 'northwest', 'aid']
# ['seiyun', 'fifth', 'photos', 'aid']
# ['batch', 'bin', 'salman', 'aid']
# ['human', 'rights', 'saudi', 'equally']
# ['programs', 'aid', 'world', 'industry']
# ['baskets', 'food', 'tons', 'benefiting']
# ['providing', 'corporate', 'support', 'local']
# ['billion', 'pledges', 'food', 'year']
# ['alrabeeah', 'million', 'mena', 'support']
# ['baghdad', 'food', 'issa', 'imports']
# ['food', 'uk', 'demand', 'bank']
# ['food', 'jeddah', 'workers', 'indian']
# ['human', 'labor', 'entire', 'development']
# ['food', 'chains', 'disruptions', 'supply']
# ['food', 'chains', 'disruptions', 'supply']
# ['paper', 'saudi', 'arabia', 'relief']
# ['interference', 'scale', 'yemen', 'aid']
# ['hunger', 'wfp', 'food', 'insecurity']
# ['salman', 'aid', 'palestinian', 'batch']
# ['billion', 'food', 'year', 'governments']
# ['yemen', 'saudi', 'projects', 'support']
# ['million', 'profits', 'donating', 'group']
# ['refugees', 'ksrelief', 'center', 'medical']
# ['western', 'gear', 'medical', 'publichealth']
# ['doctors', 'medical', 'revolution', 'latin']
# ['jakarta', 'food', 'act', 'stalls']
# ['meals', 'khalifa', 'lights', 'donation']
# ['lebanon', 'beirut', 'port', 'food']
# ['saudi', 'march', 'kingdom', 'human']
# ['food', 'insecurity', 'saying', 'wfp']
# ['human', 'rights', 'countries', 'model']
# ['labor', 'resources', 'human', 'uae']
# ['baskets', 'sudan', 'food', 'distribute']
# ['yemen', 'aid', 'guterres', 'promised']
# ['syria', 'doctors', 'medical', 'healthcare']
# ['dubai', 'payments', 'donated', 'business']
# ['uae', 'indian', 'india', 'cooperation']
# ['company', 'supply', 'healthcare', 'energy']
# ['hunger', 'food', 'acute', 'famine']
# ['unicef', 'instagram', 'im', 'donate']
# ['baskets', 'ksrelief', 'benefiting', 'food']
# ['kingdom', 'combat', 'custodian', 'human']
# ['cooperation', 'g20', 'agriculture', 'environment']
# ['seiyun', 'batch', 'aid', 'yemen']
# ['g20', 'supply', 'chains', 'coordination']
# ['kingdom', 'human', 'rights', 'measures']
# ['northeast', 'syria', 'food', 'isis']

# %% [markdown]
# From the above analysis, we can see the following relationships:
#
# * UAE → Yemen: Aid in billions in August 2020
# * UAE → UAE: The World's Tallest Donation box initiative where the Burj Khalifa in Dubai transformed into a donation box as part of the campaign aimed at providing meals to Coronavirus-hit communities across the United Arab Emirates.
# * UAE → Iran: Coronavirus relief funds
# * UAE → Iraq: Coronavirus relief funds
# * UAE → Karazkhistan: Metric tons of medical supplies and testing kits sent to Kazakhstan.
# * UAE → South Africa: UAE delivers planeload of medical supplies to South Africa
# * UAE → Sudan: Emirati aircraft carrying 38 tonnes of aid
#
#
# * Qatar → Syria: Qatar pledges food support
# * Qatar → Vanuatu: Support for cyclone hit areas
# * Qatar → Ethiopia: Qatar deliver relief aid to Ethiopian refugees
# * Qatar → Rwanda: Qatar sends tonnes of medical supplies to Rwanda
#
#
# * Saudi Arabia → Lebanon: KSrelief affiliates take part in Beirut rescue operations
# * Saudi Arabia → Palestine: The King Salman Humanitarian Aid and Relief Center (KSRelief) delivered the second batch of medical aid to the Palestine

# %%
# Run the script for Euro-Atlantic Countries

for country in eaCountries:
    print('\n\nProcessing',country,'...\n')
    dfCountry = df[df['country']==country] # Get the df for the country
    arr = dfCountry["text"].to_numpy() # Get the text as array
    corpus = arr.tolist() # Convert to list
    corpusLen = len(corpus) # Get length of list
    trainingLen = corpusLen * 0.2 # Train it on 20% of the text items
    trainingLen = int(trainingLen)
    trainArr = corpus[:trainingLen] # First 20% of corpus
    restArr = corpus[-(len(corpus)-trainingLen-4):] # Last 80% of corpus
    X = tfidf.fit_transform(trainArr) # Fit transform
    feature_names = np.array(tfidf.get_feature_names())
    responses = tfidf.transform(restArr) # TFIDF Transform
    resultsArr = [get_top_tf_idf_words(response,4) for response in responses]
    finalArr = [l.tolist() for l in resultsArr] # Final array output
    for item in finalArr: # Print the Results
        for subitem in item:
            if subitem in interestingKeywords:
                print(item)
# Out:
# Processing US ...
#
# ['food', 'hunger', 'farmers', 'global']
# ['groups', 'rumours', 'aid', 'migrants']
# ['aid', 'border', 'ngos', 'asylum']
# ['california', 'sacramento', 'newsom', 'food']
# ['beasley', 'wfp', 'sudan', 'food']
# ['updated', 'april', 'aid', 'migrants']
# ['idlib', 'province', 'groups', 'aid']
# ['faso', 'burkina', 'registration', 'aid']
# ['says', 'north', 'food', 'quintana']
# ['yemen', 'houthis', 'yemens', 'aid']
# ['food', 'insects', 'farmers', 'africa']
# ['malnutrition', 'malnourished', 'wasting', 'food']
# ['myanmars', 'abiy', 'food', 'rakhine']
# ['donated', 'japan', 'yen', 'center']
# ['food', 'says', 'farmers', 'rice']
# ['3m', 'direct', 'relief', 'providers']
# ['vegas', 'las', 'nevada', 'donation']
# ['tnh', 'aid', 'victims', 'samoa']
# ['yemen', 'aid', 'lowcock', 'email']
# ['andrés', 'food', 'says', 'kitchen']
# ['direct', 'icu', 'relief', 'reliefs']
# ['meals', 'salvation', 'food', 'hollander']
# ['humanitarianism', 'explore', 'genocide', 'crises']
# ['subsaharan', 'food', 'climate', 'africa']
# ['fao', 'yemen', 'food', 'ahmed']
# ['usaid', 'programs', 'aid', 'foreign']
# ['billion', 'aid', 'grants', 'spending']
# ['aid', 'funding', 'generosity', 'administration']
# ['food', 'beasley', 'syria', 'vulnerable']
# ['cross', 'red', 'donations', 'party']
# ['food', 'crops', 'supply', 'local']
# ['food', 'crops', 'supply', 'local']
# ['beasley', 'hunger', 'food', 'million']
# ['children', 'malnourished', 'food', 'malnutrition']
# ['shop', 'donated', 'retailer', 'donate']
# ['shop', 'donated', 'retailer', 'donate']
# ['pakistan', 'aid', 'pakistans', 'groups']
# ['food', 'mr', 'says', 'beasley']
# ['yemen', 'aid', 'houthis', 'uae']
# ['forum', 'riyadh', 'humanitarian', 'rabeeah']
# ['yemen', 'houthis', 'aid', 'programs']
# ['aid', 'yemen', 'rebels', 'programs']
# ['yemen', 'houthis', 'aid', 'programs']
# ['yemen', 'wfp', 'yemeni', 'aid']
# ['charities', 'relief', 'haiti', 'supplies']
# ['funding', 'aid', 'billion', 'spending']
# ['afloat', 'african', 'societies', 'fund']
# ['food', 'insects', 'farmers', 'africa']
# ['beasley', 'wfp', 'sudan', 'food']
# ['aid', 'relief', 'money', 'agency']
# ['aid', 'relief', 'money', 'agency']
# ['advertisement', 'aid', 'relief', 'money']
# ['advertisement', 'aid', 'relief', 'money']
# ['3m', 'supplies', 'respirators', 'medical']
# ['aid', 'commitments', 'analysis', 'funding']
# ['nonprofits', 'organizations', 'fund', 'donors']
# ['organizations', 'eu', 'international', 'cooperation']
# ['africa', 'food', 'disruptions', 'locusts']
# ['aid', '26', 'march', 'ngos']
# ['china', 'donated', 'air', 'flight']
# ['food', 'insecurity', 'husain', 'acute']
# ['ap', 'venezuela', 'aid', 'nations']
# ['masks', 'n95', 'shipments', 'medical']
# ['aid', 'sanaa', 'houthi', 'yemen']
# ['yemen', 'aid', 'houthis', 'uae']
# ['food', 'saturday', 'sacramento', 'mock']
# ['chinaafrica', 'china', 'africa', 'cooperation']
# ['aid', 'commitments', 'analysis', 'funding']
# ['aid', 'conversation', 'audience', 'readers']
# ['latin', 'region', 'food', 'wfp']
# ['department', 'assistance', 'aid', '64']
# ['beasley', 'food', 'famines', 'facing']
# ['food', 'hunger', 'delhi', 'hungry']
# ['iran', 'yemen', 'aid', 'usaid']
# ['expo', 'uae', 'cooperation', 'international']
# ['husain', 'grains', 'wfp', 'food']
# ['wheat', 'food', 'afghanistan', 'afghanistans']
# ['aid', 'agency', 'feet', 'funding']
# ['aid', 'analysis', 'commitments', 'billion']
# ['sahel', 'food', 'le', 'products']
# ['aid', 'ngos', 'programmes', 'ngo']
# ['masks', 'n95', 'shipments', 'medical']
# ['dog', 'alaska', 'food', 'delta']
# ['yemen', 'aid', 'pledges', 'war']
# ['sector', 'aid', 'organisations', 'humanitarians']
# ['mutual', 'nhs', 'aid', 'volunteers']
# ['usaid', 'ppe', 'supplies', 'aid']
# ['aid', 'yemen', 'rebels', 'programs']
# ['updated', 'programmes', 'aid', 'april']
# ['russia', 'moscow', 'medical', 'kremlin']
# ['equipment', 'schaffner', 'medical', 'russia']
# ['food', 'rations', 'yemen', 'aid']
# ['food', 'rations', 'yemen', 'aid']
# ['aid', 'agency', 'funding', 'protective']
# ['masks', 'n95', 'shipments', 'medical']
# ['food', 'meat', 'milk', 'processing']
# ['refugees', 'technological', 'rights', 'human']
# ['africa', 'food', 'disruptions', 'locusts']
# ['aid', 'relief', 'money', 'agency']
# ['aid', 'relief', 'money', 'agency']
# ['direct', 'software', 'borderlands', 'relief']
# ['organizations', 'humanitarian', 'funding', 'violence']
# ['food', 'hunger', 'starvation', 'hussein']
# ['food', 'children', 'meals', 'europeans']
# ['humanitarian', 'response', 'plan', 'covid19']
# ['dog', 'alaska', 'food', 'delta']
# ['aid', 'funding', 'generosity', 'administration']
# ['direct', 'relief', 'protective', 'health']
# ['aid', 'maxman', 'panelists', 'oxfam']
# ['cp', 'canadian', 'food', 'charities']
# ['iran', 'yemen', 'aid', 'reported']
# ['yemen', 'houthis', 'aid', 'yemens']
# ['runners', 'food', 'ms', 'nonprofits']
# ['humanitarians', 'aid', 'change', 'ngos']
# ['volunteers', 'click', 'meals', 'food']
# ['trust', 'ebola', 'aid', 'mistrust']
# ['syria', 'russia', 'syrians', 'aid']
# ['crossing', 'mandate', 'northwest', 'aid']
# ['hunger', 'food', 'wfps', 'tide']
# ['investing', 'meals', 'nutrition', 'food']
# ['masks', 'n95', 'shipments', 'medical']
# ['kay', 'mary', 'sanitizer', 'donated']
# ['fontaine', 'says', 'aid', 'countries']
# ['sporting', 'golf', 'goods', 'donation']
# ['yemen', 'aid', 'pledges', 'war']
# ['taiwan', 'taiwans', 'masks', 'donating']
# ['beasley', 'wfp', 'million', 'food']
# ['novel', 'medical', 'wuhan', 'feb']
# ['aid', 'commitments', 'analysis', 'funding']
# ['donated', 'million', 'company', 'york']
# ['oxfam', 'food', 'hunger', 'vera']
# ['medical', 'quality', 'export', 'respirators']
# ['food', 'hunger', 'delhi', 'hungry']
# ['funding', 'aid', 'assistance', 'critical']
# ['children', 'malnourished', 'food', 'malnutrition']
# ['dog', 'alaska', 'food', 'humane']
# ['dog', 'alaska', 'food', 'humane']
# ['xi', 'chinas', 'global', 'cooperation']
# ['frances', 'aid', 'moeti', 'continent']
# ['northeast', 'bab', 'northwest', 'aid']
# ['crossing', 'mandate', 'northwest', 'aid']
# ['guterres', 'rights', 'human', 'package']
# ['nutrition', 'herbalife', 'hunger', 'food']
#
#
# Processing UK ...
#
# ['sure', 'countries', 'support', 'multilateral']
# ['sales', 'euros', 'said', 'donated']
# ['putin', 'russia', 'aid', 'moscow']
# ['uk', 'tackle', 'support', 'world']
# ['venezuelan', 'venezuela', 'rights', 'human']
# ['food', 'felix', 'surplus', 'project']
# ['beasley', 'food', 'countries', 'revenues']
# ['aids', 'thatcher', 'rights', 'human']
# ['footballers', 'clubs', 'donation', 'lineker']
# ['refugees', 'uganda', 'wfp', 'food']
# ['yemen', 'lowcock', 'aid', 'country']
# ['africa', 'castro', 'egeland', 'aid']
# ['fund', 'cares', 'donations', 'modi']
# ['fund', 'cares', 'donations', 'modi']
# ['yemens', 'yemen', 'probability', 'aid']
# ['jewellery', 'proceeds', 'donated', 'brand']
# ['yemen', 'probability', 'reuters', 'aid']
# ['africa', 'dfid', 'aid', 'merger']
# ['haiti', 'distributing', '19', 'food']
# ['food', 'hunger', 'world', 'people']
# ['food', 'farmers', 'banks', 'farms']
# ['aid', 'yemen', 'grande', 'arabia']
# ['beasley', 'food', 'starvation', 'wfp']
# ['food', 'africa', 'castro', 'malawi']
# ['gaza', 'healthcare', 'human', 'refugees']
# ['ventilators', 'cuomo', 'equipment', 'medical']
# ['sudan', 'noncovid', 'food', 'poorer']
# ['goodbye', 'rain', 'donate', 'lifesaving']
# ['yemens', 'dr', 'medical', 'sahloul']
# ['dfid', 'aid', 'pm', 'cameron']
# ['china', 'global', 'eu', 'cooperation']
# ['archie', 'harry', 'meghan', 'donations']
# ['iran', 'sanctions', 'iranian', 'medical']
# ['food', 'africa', 'castro', 'moeti']
# ['food', 'desert', 'yemen', 'insecurity']
# ['food', 'wfp', 'beasley', 'report']
# ['food', 'nhs', 'chi', 'ukraine']
# ['food', 'india', 'vendors', 'roadside']
# ['russian', 'medical', 'doctors', 'putin']
# ['food', 'wfp', 'report', 'programme']
# ['tonne', 'wheat', 'fao', 'food']
# ['dfid', 'aid', 'funding', 'poverty']
# ['saudi', 'yemen', 'coalition', 'aid']
# ['kumar', 'food', 'indias', 'welfare']
# ['wfp', 'insecurity', 'food', 'foodinsecure']
# ['food', 'felix', 'surplus', 'project']
# ['fund', 'cares', 'pm', 'rupees']
# ['afghanistan', 'food', 'children', 'bishop']
# ['dfid', 'uk', 'foreign', 'aid']
# ['beasley', 'food', 'famine', 'oil']
# ['ma', 'foundation', 'jack', 'donations']
# ['beasley', 'food', 'sudan', 'shocks']
# ['country', 'support', 'tobias', 'refugees']
# ['food', 'riots', 'fao', 'countries']
# ['sudan', 'food', 'yemen', 'millions']
# ['development', 'aid', 'foreign', 'johnson']
# ['sector', 'aid', 'humanitarians', 'international']
# ['donated', 'donation', 'generously', 'star']
# ['donated', 'donation', 'generously', 'star']
# ['food', 'felix', 'charities', 'fresh']
# ['plants', 'plant', 'meat', 'food']
# ['korea', 'north', 'food', 'change']
# ['3m', 'food', 'farm', 'farmers']
# ['usaid', 'yemen', 'aid', 'houthi']
# ['children', 'aid', 'lamont', 'exploitation']
# ['food', 'hunger', 'milk', 'million']
# ['food', 'farms', 'demand', 'grain']
# ['houthi', 'aid', 'yemen', 'donors']
# ['yemen', 'aid', 'usaid', 'houthi']
# ['prince', 'jack', 'meals', 'help']
# ['tripoli', 'supply', 'said', 'drones']
# ['persons', 'plan', 'support', 'accelerated']
# ['houthis', 'yemens', 'yemen', 'aid']
# ['beasley', 'food', 'famine', 'starvation']
# ['mexico', 'meals', 'food', 'skills']
# ['crises', 'bangladesh', 'humanitarians', 'aid']
# ['maduro', 'venezuela', 'guaido', 'aid']
# ['famines', 'food', 'countries', 'wfp']
# ['meals', 'food', 'skills', 'highend']
# ['felix', 'food', 'surplus', 'london']
# ['donated', 'schwarzenegger', 'beyonce', 'instagram']
# ['food', 'document', 'banks', 'demand']
# ['countries', 'developing', 'syria', 'aid']
# ['yemen', 'money', 'wailing', 'support']
# ['dfid', 'poverty', 'aid', 'development']
# ['blood', 'cross', 'red', 'donations']
# ['farmers', 'food', 'farm', 'adjust']
# ['cuts', 'aid', 'development', 'scrutiny']
# ['yemen', 'aid', 'donors', '135bn']
# ['son', 'neighbours', 'donation', 'korean']
# ['mrs', 'eu', 'fund', 'proposals']
# ['food', 'letter', 'g20', 'farmers']
# ['wfp', 'food', 'johannesburg', 'economies']
# ['lebanon', 'blast', 'parcels', 'food']
# ['yemen', 'aid', 'arabia', 'saudi']
# ['ronnie', 'selfemployed', 'financial', 'help']
# ['vanuatu', 'cyclone', 'supplies', 'relief']
#
#
# Processing DE ...
# ['people', 'food', 'children', 'foundation']
# ['wfp', 'food', 'people', 'starvation']
# ['taliban', 'afghanistan', 'health', 'helped']
# ['care', 'health', 'zimbabwe', 'medical']
# ['food', 'africa', 'wfp', 'zimbabwe']
# ['crisis', 'human', 'far', 'corona']
# ['wfp', 'food', 'arif', 'hunger']
#
#
# Processing FR ...
#
# ['iran', 'iranian', 'march', 'help']
# ['food', 'wfp', 'report', 'number']
# ['northeast', 'syria', 'supplies', 'medical']
# ['russia', 'russian', 'medical', 'plane']
# ['nigeria', 'production', 'farmers', 'food']
# ['idlib', 'syria', 'aid', 'displaced']
# ['communities', 'food', 'ensure', 'starvation']
# ['iraq', 'iraqis', 'food', 'iraqi']
# ['donations', 'blood', 'london', 'italy']
# ['yemen', 'aid', 'arabia', 'saudi']
# ['food', 'children', 'hundreds', 'supply']
# ['food', 'children', 'hundreds', 'supply']
# ['russia', 'moscow', 'medical', 'sent']
# ['children', 'malnutrition', 'hunger', 'food']
# ['yemen', 'saudi', 'aid', 'conference']
# ['yemen', 'food', 'report', 'grande']
# ['food', 'children', 'hundreds', 'supply']
# ['food', 'children', 'hundreds', 'supply']
# ['russia', 'russian', 'medical', 'plane']
# ['zimbabwe', 'food', 'million', 'people']
# ['beasley', 'food', 'wfp', 'sudan']
# ['yemen', 'food', 'worlds', 'report']
# ['northeast', 'syria', 'deliver', 'food']
# ['yemen', 'food', 'report', 'insecurity']
# ['northeast', 'syria', 'deliver', 'food']
# ['unicef', 'children', 'yemen', 'aid']
# ['yemen', 'saudi', 'aid', 'arabia']

# %% [markdown]
# * US → Japan: YOSHIKI Donates 10 Million Yen To Japan's National Center For Global Health And Medicine
# * US → Yemen: U.S. announces 225 million USD in emergency aid to Yemen
# * US → Venezuela: The United States will be committing USD36 million in aid to Venezuela, as part of a United Nations program to provide relief to the country
# * US → Syria: The United States Announces Additional Humanitarian Assistance for the Syrian People
# * Taiwan → US: Taiwan Donates Over 51 Million Masks to Countries Worldwide
#
#
# * UK → Vanuatu: UK emergency supplies for cyclone victims arrive in Vanuatu
# * UK → Yemen: The UK pledged $196 million this year
# * UK → Bangladesh: UK announces extra £87 million funding for Rohingya crisis
# * UK → Sudan: Emergency food relief from UK Government for vulnerable households in South Sudan
# * UK → Uganda: WFP In Uganda Welcomes UK Contribution For Refugees
#
#
# * Germany → Zimbabwe: Amid COVID-19 crises, Germany donates to protect African countries
#
#
# Mostly, News in France 'reported' humanitarian efforts rather than making humanitarian efforts:
#
# * France → Syria: France sends medical aid to Assad's Syria after deal
# * France → Syria: France unlocked an 50 million euros for humanitarian aid to Syria, half of which will be destined for the Idlib region.

# %%
# Run the script for New Global Media Players

for country in ngmpCountries:
    print('\n\nProcessing',country,'...\n')
    dfCountry = df[df['country']==country] # Get the df for the country
    arr = dfCountry["text"].to_numpy() # Get the text as array
    corpus = arr.tolist() # Convert to list
    corpusLen = len(corpus) # Get length of list
    trainingLen = corpusLen * 0.2 # Train it on 20% of the text items
    trainingLen = int(trainingLen)
    trainArr = corpus[:trainingLen] # First 20% of corpus
    restArr = corpus[-(len(corpus)-trainingLen-4):] # Last 80% of corpus
    X = tfidf.fit_transform(trainArr) # Fit transform
    feature_names = np.array(tfidf.get_feature_names())
    responses = tfidf.transform(restArr) # TFIDF Transform
    resultsArr = [get_top_tf_idf_words(response,4) for response in responses]
    finalArr = [l.tolist() for l in resultsArr] # Final array output
    for item in finalArr: # Print the Results
        for subitem in item:
            if subitem in interestingKeywords:
                print(item)
# Out:
# Processing CN ...
#
# ['kyrgyzstan', 'medical', 'china', 'du']
# ['wfp', 'hunger', 'zimbabwe', 'food']
# ['china', 'cooperation', 'sides', 'mohammed']
# ['epidemic', 'treatment', 'china', 'medical']
# ['africa', 'kenya', 'african', 'food']
# ['report', 'support', 'recovery', 'roadmap']
# ['xi', 'chinese', 'cooperation', 'china']
# ['rights', 'china', 'human', 'poverty']
# ['unemployment', 'insurance', 'relief', 'hearing']
# ['verde', 'cape', 'donation', 'archipelago']
# ['dujarric', 'humanitarian', 'food', 'said']
# ['dujarric', 'humanitarian', 'food', 'said']
# ['cooperation', 'china', 'world', 'global']
# ['college', 'medical', 'wuhan', 'hospital']
# ['lowcock', 'fund', 'money', 'dujarric']
# ['china', 'solidarity', 'cooperation', 'wha']
# ['myanmar', '90000', 'pyi', 'donation']
# ['rights', 'human', 'epidemic', 'lives']
# ['globalization', 'outbreak', 'cooperation', 'global']
# ['kyrgyzstan', 'medical', 'du', 'batch']
# ['rights', 'human', 'law', 'china']
# ['zimbabwe', 'mnangagwa', 'guo', 'donation']
# ['ecw', 'education', 'fund', 'youth']
# ['lebanese', 'donations', 'cabinet', 'lebanon']
# ['xinjiang', 'rights', 'human', 'act']
# ['cooperation', 'china', 'wang', 'countries']
# ['discrimination', 'rights', 'human', 'china']
# ['rights', 'china', 'human', 'medical']
# ['rights', 'china', 'human', 'medical']
# ['cooperation', 'china', 'wang', 'countries']
# ['report', 'support', 'recovery', 'roadmap']
# ['report', 'human', 'coordinated', 'livelihoods']
# ['food', 'crises', 'insecurity', 'network']
# ['yemen', 'guterres', 'aid', 'programs']
# ['food', 'qu', 'chains', 'supply']
# ['food', 'qu', 'chains', 'supply']
# ['food', 'percent', 'syria', 'million']
# ['xi', 'chinese', 'china', 'cooperation']
# ['icrc', 'zones', 'conflict', 'medical']
# ['china', 'council', 'cooperation', 'security']
# ['food', 'nutrition', 'systems', 'children']
# ['release', 'press', 'valued', 'support']
# ['ocha', 'humanitarian', 'information', 'set']
# ['students', 'food', 'volunteer', 'informal']
# ['unemployment', 'insurance', 'relief', 'hearing']
# ['wang', 'china', 'cooperation', 'economy']
# ['asean', 'need', 'regional', 'cooperation']
# ['aid', 'china', 'foreign', 'debt']
# ['yemen', '241', 'yemenis', 'aid']
# ['yemen', 'saudi', 'arabia', 'aid']
# ['food', 'igad', 'fao', 'region']
# ['rights', 'china', 'human', 'wuhan']
# ['asean', 'need', 'regional', 'cooperation']
# ['au', 'africa', 'fund', 'currency']
# ['china', 'strength', 'chinese', 'support']
# ['medshare', 'donation', 'gowns', 'cocacola']
# ['states', 'deaths', 'cooperation', 'united']
# ['food', 'lowcock', 'average', 'syria']
# ['medical', 'defense', 'myanmar', 'china']
# ['food', 'supply', 'ministers', 'chains']
# ['food', 'supply', 'ministers', 'chains']
# ['somalia', 'testing', 'support', 'swan']
# ['asean', 'defense', 'ministers', 'cooperation']
# ['yuan', 'million', 'medical', 'pneumonia']
# ['south', 'africa', 'donation', 'spokesperson']
# ['china', 'video', 'global', 'cooperation']
# ['african', 'africa', 'china', 'medical']
# ['poor', 'india', 'lockdown', 'food']
# ['ngo', 'donations', 'report', 'chinese']
# ['food', 'fao', 'security', 'programme']
# ['wang', 'china', 'cooperation', 'economy']
# ['cuba', 'cuban', 'sanctions', 'medical']
# ['china', 'outbreak', 'cpc', 'cooperation']
# ['somalia', 'insecurity', 'food', 'acute']
# ['brics', 'global', 'countries', 'cooperation']
# ['food', 'zhang', 'development', 'hunger']
# ['cuba', 'cuban', 'medical', 'health']
# ['xi', 'china', 'cooperation', 'speech']
# ['hunger', 'food', 'insecurity', 'action']
# ['wang', 'cooperation', 'china', 'algeria']
# ['china', 'african', 'cooperation', 'botswana']
# ['food', 'prices', 'production', 'supply']
# ['food', 'prices', 'production', 'supply']
# ['medshare', 'san', 'donation', 'chinese']
# ['wfp', 'food', 'faso', 'mali']
# ['food', 'chains', 'disruptions', 'supply']
# ['food', 'chains', 'disruptions', 'supply']
# ['cuba', 'cuban', 'medical', 'health']
# ['lowcock', 'fund', 'money', 'dujarric']
# ['zimbabwe', 'mnangagwa', 'guo', 'donation']
# ['rights', 'china', 'human', 'lives']
# ['xi', 'chinese', 'cooperation', 'china']
# ['navarro', 'washington', 'supply', 'chains']
# ['syria', 'pedersen', 'geir', 'food']
# ['food', 'panic', 'rice', 'supply']
# ['food', 'panic', 'rice', 'supply']
#
#
# Processing RU ...
#
# ['venezuelan', 'ministry', 'venezuela', 'medical']
# ['cooperation', 'ryabkov', 'global', 'healthcare']
# ['yemen', 'conference', 'transparency', 'relief']
# ['syria', 'syrian', 'east', 'aid']
# ['iran', 'terrorism', 'medical', 'iranian']
# ['belarus', 'plane', 'minsk', 'aid']
# ['rdif', 'cargo', 'fund', 'ventilators']
# ['wfp', 'yemen', 'children', 'food']
# ['refugee', 'appeal', 'guterres', 'support']
# ['sector', 'food', 'nonprofit', 'founder']
# ['scientists', 'protocol', 'cooperation', 'sciences']
# ['unicef', 'children', 'fund', 'worldwide']
# ['cuba', 'medical', 'brigade', 'dr']
# ['lebanese', 'wfp', 'food', 'lebanon']
# ['venezuela', 'venezuelan', 'deliveries', 'medical']
# ['icrc', 'syria', 'volunteers', 'aid']
# ['medical', 'said', 'sent', 'russia']
# ['virtual', 'food', 'bank', '000']
# ['syria', 'release', 'fund', 'communities']
# ['kazakhstan', 'cooperation', 'grateful', 'security']
# ['russia', 'kremlin', 'equipment', 'medical']
# ['kyrgyzstan', 'russian', 'doctors', 'medical']
# ['human', 'sanctions', 'syrian', 'quotes']
# ['food', 'report', 'crises', 'vulnerable']
# ['bukele', 'rights', 'human', 'really']
# ['unicef', 'venezuela', 'children', 'fund']
# ['reaffirmed', 'mirziyoyev', 'uzbek', 'cooperation']
# ['aspect', 'effectively', 'cooperation', 'peskov']
# ['icrc', 'balzamova', 'distribution', 'food']
# ['sanctions', 'rights', 'human', 'medical']
# ['sanctions', 'rights', 'human', 'medical']
# ['committee', 'food', 'travel', 'advice']
# ['russian', 'antonov', 'carrying', 'aid']
# ['china', 'geng', 'cooperation', 'spreading']
# ['wfp', 'yemen', 'food', 'spokesperson']
#
#
# Processing IR ...
#
# ['fao', 'food', 'agriculture', 'farmers']
# ['request', 'borrell', 'imf', 'fund']
# ['food', 'africa', 'farmers', 'markets']
# ['help', 'irgc', 'nation', 'commander']
# ['korea', 'north', 'food', 'widespread']
# ['imf', 'fund', 'monetary', 'funding']
# ['food', 'children', 'nutritional', 'chief']
# ['food', 'fao', 'vulnerable', 'supply']
# ['food', 'fao', 'vulnerable', 'supply']
# ['imf', 'fund', 'monetary', 'request']
# ['economic', 'human', 'social', 'distance']
# ['envoy', 'china', 'aid', 'sending']
# ['iaea', 'iran', 'qaribabadi', 'fund']
# ['fund', 'hemmati', 'imf', 'monetary']
# ['consignment', 'aid', 'sent', 'weighs']
# ['fao', 'food', 'agriculture', 'farmers']
# ['mayor', 'municipality', 'send', 'aid']
# ['professor', 'aid', 'policies', 'justified']
# ['consignment', 'sunday', 'iran', 'aid']
# ['venezuela', 'carrying', 'irans', 'aid']
# ['coordinated', 'support', 'impacts', 'socioeconomic']
# ['food', 'nutrition', 'systems', 'children']
# ['fao', 'food', 'agriculture', 'farmers']
# ['terrorism', 'iran', 'zarif', 'medical']
# ['japanese', 'solidarity', 'japan', 'support']
# ['iran', 'sent', 'georgia', 'aid']
# ['donations', 'chinese', 'iran', 'flights']
# ['yemen', 'food', 'acute', 'facing']
# ['unhcr', 'bridge', 'support', 'air']
# ['readiness', 'fm', 'mutual', 'cooperation']
# ['food', 'fao', 'vulnerable', 'supply']
# ['food', 'fao', 'vulnerable', 'supply']
# ['food', 'children', 'meals', 'school']
# ['unhcr', 'refugees', 'support', 'statement']
# ['iran', 'donation', 'economy', 'opec']
# ['aid', 'organizations', 'international', 'affairs']
# ['sudan', 'africa', 'poorer', 'food']
# ['food', 'children', 'impending', 'nutritional']
# ['relief', 'iran', 'sanctions', 'direct']
# ['wfp', 'food', 'insecurity', 'economies']
# ['4030', 'say', 'center', 'aid']
# ['food', 'children', 'impending', 'nutritional']
# ['consignment', 'qatar', 'iranqatar', 'aid']
# ['food', 'shortages', 'prices', 'price']
# ['food', 'hunger', 'acute', 'double']
# ['packages', 'relief', 'commander', 'irgc']
# ['iran', 'aid', 'sent', 'korea']
# ['relief', 'iran', 'sanctions', 'eu']
# ['turkmenistan', 'donated', 'aid', 'iran']
# ['turkmenistan', 'donated', 'aid', 'iran']
#
#
# Processing TR ...
#
# ['medical', 'cargo', 'china', 'turkish']
# ['yemen', 'funding', 'case', 'aid']
# ['food', 'korea', 'shortages', 'widespread']
# ['iraq', 'sends', 'medical', 'turkey']
# ['rural', 'food', 'poverty', 'action']
# ['erdoğan', 'nato', 'importance', 'medical']
# ['masks', 'shipments', 'n95', 'medical']
# ['aid', 'medical', 'cavusoglu', 'supplier']
# ['aid', 'medical', 'cavusoglu', 'supplier']
# ['rural', 'production', 'fund', 'people']
# ['turkey', 'medical', 'azerbaijan', 'council']
# ['malnutrition', 'food', 'children', 'hunger']
# ['africa', 'south', 'erdoan', 'medical']
# ['council', 'cooperation', 'trade', 'member']
# ['equipment', 'medical', 'turkey', 'israel']
# ['zimbabwe', 'sudan', 'multilateral', 'fund']
# ['rights', 'human', 'crisis', 'chief']
# ['moscow', 'russia', 'medical', 'sent']
# ['diseases', 'cooperation', 'experience', 'international']
# ['guinea', 'fund', 'material', 'alarm']
# ['guterres', 'support', 'civilians', 'ceasefire']
# ['afghan', 'pakistan', 'peace', 'cooperation']
# ['food', 'lockdown', 'poor', 'migrant']
# ['qatar', 'qatari', 'message', 'support']
# ['food', 'remittances', 'zimbabwe', 'trt']
# ['turkey', 'aid', 'tika', 'medical']
# ['turkey', 'aid', 'tika', 'medical']
# ['chad', 'sends', 'turkey', 'aid']
# ['blast', 'beirut', 'food', 'lebanon']
# ['cavusoglu', 'turkey', 'phone', 'cooperation']
# ['tunisia', 'supplies', 'medical', 'turkey']
# ['chad', 'supplies', 'medical', 'aircraft']
# ['food', 'exports', 'developing', 'feed']
# ['taliban', 'afghanistan', 'aid', 'commission']

# %% [markdown]
# * China → Kyrgyzstan: China delivers more medical supplies to Kyrgyzstan
# * China → Zimbabwe: Food Assistance
# * China → Cape Verde: Medical Donation
# * Myanmar → China: Medical Equipment Donation
# * China → Lebanon: China donates more medical supplies to Lebanon
# * China → Syria: China Contributes USD2 Million To WFP's Response Inside Syria
# * US → China: Non-profit donates to China
# * China → Botswana: China continues to support Botswana
#
#
# * Russia → Venezuela: Russia Sends Humanitarian Support In Medicine to Venezuela
# * Russia → Yemen: Russia earmarks USD4 mln to provide food assistance to Yemen
# * Russia → US: Russia sends planeload of medical supplies to US
# * Russia → Kyrgyzstan: Russian military medics arrive in Kyrgyzstan
#
#
# * China → Iran: China to send new humanitarian aid shipments to Iran.
# * Iran → Kyrgyzstan: Iran delivers second shipment of anti-corona aid to Kyrgyzstan
# * Iran → Venezuela: Venezuela says flight arrives from Iran carrying COVID-19 aid
# * Japan → Iran: WFP Iran receives historical contribution from Japan
# * Georgia → Iran: Georgian pharmacists dispatch humanitarian aid cargo to Iran
# * Qatar → Iran: Qatar delivers 2nd consignment to Iran to fight coronavirus
# * South Korea → Iran: S. Korea sends humanitarian medical aid worth USD500000 to Iran
# * Turkmenistan → Iran: Turkmenistan sends humanitarian aid to neighboring Iran
#
#
# * Turkey → Yemen: Turkish charity distributes food aid in Yemen
# * Turkey → Iraq: Turkey sends medical aid to Iraq
# * Turkey → Azerbaijan: Turkey sends Azerbaijan medical aid to fight COVID-19
# * Turkey → South Africa: COVID-19: Turkish medical aid arrives in South Africa
# * Turkey → Afghanistan: Turkish aid agency sends medical aid to Afghanistan
# * Turkey → Chad: Turkey sends medical aid to Chad
# * Turkey → Lebanon: Turkish agency distributes 400 tons of wheat in Lebanon
# * Turkey → Tunisia: Turkey sends medical supplies to Tunisia amid outbreak

# %% [markdown]
# ## Data for Visualisation
#
# Now that we have the direction of where the aid is coming from and where is it moving, we can represent it on a graph using `AmChart's map module`. To do that, we need latitude and longitudes of origin and destination countries.
#
# We can use `OpenStreetMap.org` to get the lat, long. To make a `GET request`, we will need to use the `request` library.

# %%
# Test run

address = 'Pakistan'
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

response = requests.get(url).json()
print(response[0]["lat"])
print(response[0]["lon"])
# Out:
# 30.3308401
# 71.247499

# %%
# Now running with New Global Media Players

humanitarianCountries = [
    ['Turkey', 'Yemen'],
    ['Turkey', 'Iraq'],
    ['Turkey', 'Azerbaijan'],
    ['Turkey', 'South Africa'],
    ['Turkey', 'Afghanistan'],
    ['Turkey', 'Chad'],
    ['Turkey', 'Lebanon'],
    ['Turkey', 'Tunisia'],
    
    ['China', 'Iran'],
    ['Iran', 'Kyrgyzstan'],
    ['Iran', 'Venezuela'],
    ['Japan', 'Iran'],
    ['Georgia', 'Iran'],
    ['Qatar', 'Iran'],
    ['South Korea', 'Iran'],
    ['Turkmenistan', 'Iran'],
    
    
    ['China', 'Kyrgyzstan'],
    ['China', 'Zimbabwe'],
    ['China', 'Cape Verde'],
    ['Myanmar', 'China'],
    ['China', 'Lebanon'],
    ['China', 'Syria'],
    ['US', 'China'],
    ['China', 'Botswana'],
    ['Russia', 'Venezuela'],
    ['Russia', 'Yemen'],
    ['Russia', 'United States'],
    ['Russia', 'Kyrgyzstan'],
]

# %%
# Make a function to get Lat Long in a list

def getLatLong(address):
    url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'
    response = requests.get(url).json()
    return [response[0]["lat"], response[0]["lon"]]

# %%
# Test run

getLatLong('Yemen')
# Out:
# ['16.3471243', '47.8915271']

# %%
# Print lat long in the right format that can be copy-pasted into AmCharts

for countries in humanitarianCountries:
    latLongA = getLatLong(countries[0])
    latLongB = getLatLong(countries[1])
    print("{ latitudes: ["+latLongA[0]+", "+latLongB[0]+"], longitudes: ["+latLongA[1]+", "+latLongB[1]+"]},")
# Out:
# { latitudes: [38.9597594, 16.3471243], longitudes: [34.9249653, 47.8915271]},
# { latitudes: [38.9597594, 33.0955793], longitudes: [34.9249653, 44.1749775]},
# { latitudes: [38.9597594, 40.3936294], longitudes: [34.9249653, 47.7872508]},
# { latitudes: [38.9597594, -28.8166236], longitudes: [34.9249653, 24.991639]},
# { latitudes: [38.9597594, 33.7680065], longitudes: [34.9249653, 66.2385139]},
# { latitudes: [38.9597594, 15.6134137], longitudes: [34.9249653, 19.0156172]},
# { latitudes: [38.9597594, 33.8750629], longitudes: [34.9249653, 35.843409]},
# { latitudes: [38.9597594, 33.8439408], longitudes: [34.9249653, 9.400138]},
# { latitudes: [35.000074, 32.6475314], longitudes: [104.999927, 54.5643516]},
# { latitudes: [32.6475314, 41.5089324], longitudes: [54.5643516, 74.724091]},
# { latitudes: [32.6475314, 8.0018709], longitudes: [54.5643516, -66.1109318]},
# { latitudes: [36.5748441, 32.6475314], longitudes: [139.2394179, 54.5643516]},
# { latitudes: [32.3293809, 32.6475314], longitudes: [-83.1137366, 54.5643516]},
# { latitudes: [25.3336984, 32.6475314], longitudes: [51.2295295, 54.5643516]},
# { latitudes: [36.638392, 32.6475314], longitudes: [127.6961188, 54.5643516]},
# { latitudes: [39.3763807, 32.6475314], longitudes: [59.3924609, 54.5643516]},
# { latitudes: [35.000074, 41.5089324], longitudes: [104.999927, 74.724091]},
# { latitudes: [35.000074, -18.4554963], longitudes: [104.999927, 29.7468414]},
# { latitudes: [35.000074, 16.0000552], longitudes: [104.999927, -24.0083947]},
# { latitudes: [17.1750495, 35.000074], longitudes: [95.9999652, 104.999927]},
# { latitudes: [35.000074, 33.8750629], longitudes: [104.999927, 35.843409]},
# { latitudes: [35.000074, 34.6401861], longitudes: [104.999927, 39.0494106]},
# { latitudes: [39.7837304, 35.000074], longitudes: [-100.4458825, 104.999927]},
# { latitudes: [35.000074, -23.1681782], longitudes: [104.999927, 24.5928742]},
# { latitudes: [64.6863136, 8.0018709], longitudes: [97.7453061, -66.1109318]},
# { latitudes: [64.6863136, 16.3471243], longitudes: [97.7453061, 47.8915271]},
# { latitudes: [64.6863136, 39.7837304], longitudes: [97.7453061, -100.4458825]},
# { latitudes: [64.6863136, 41.5089324], longitudes: [97.7453061, 74.724091]},

# %%
# Next, we need to add markers on the map, we can do this using another loop

# Function to remove duplicates from list

def remove_duplicates(l):
    return list(set(l))

# Make a list from list of lists

allCountries = [item for sublist in humanitarianCountries for item in sublist]
uniqueCountries = remove_duplicates(allCountries)

# Print JS object using a loop

for country in uniqueCountries:
    latLong = getLatLong(country)
    print('{')
    print('svgPath: targetSVG,')
    print('title: "'+country+'",')
    print('latitude: '+latLong[0]+',')
    print('longitude: '+latLong[1]+',')
    print('scale: 0.5')
    print('},')
# Out:
# {
# svgPath: targetSVG,
# title: "Chad",
# latitude: 15.6134137,
# longitude: 19.0156172,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Myanmar",
# latitude: 17.1750495,
# longitude: 95.9999652,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Syria",
# latitude: 34.6401861,
# longitude: 39.0494106,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Russia",
# latitude: 64.6863136,
# longitude: 97.7453061,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Venezuela",
# latitude: 8.0018709,
# longitude: -66.1109318,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Botswana",
# latitude: -23.1681782,
# longitude: 24.5928742,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "South Korea",
# latitude: 36.638392,
# longitude: 127.6961188,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Qatar",
# latitude: 25.3336984,
# longitude: 51.2295295,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Iraq",
# latitude: 33.0955793,
# longitude: 44.1749775,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Cape Verde",
# latitude: 16.0000552,
# longitude: -24.0083947,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "US",
# latitude: 39.7837304,
# longitude: -100.4458825,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Azerbaijan",
# latitude: 40.3936294,
# longitude: 47.7872508,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Japan",
# latitude: 36.5748441,
# longitude: 139.2394179,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Yemen",
# latitude: 16.3471243,
# longitude: 47.8915271,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Lebanon",
# latitude: 33.8750629,
# longitude: 35.843409,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "United States",
# latitude: 39.7837304,
# longitude: -100.4458825,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Iran",
# latitude: 32.6475314,
# longitude: 54.5643516,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Kyrgyzstan",
# latitude: 41.5089324,
# longitude: 74.724091,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Tunisia",
# latitude: 33.8439408,
# longitude: 9.400138,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "China",
# latitude: 35.000074,
# longitude: 104.999927,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "South Africa",
# latitude: -28.8166236,
# longitude: 24.991639,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Zimbabwe",
# latitude: -18.4554963,
# longitude: 29.7468414,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Turkmenistan",
# latitude: 39.3763807,
# longitude: 59.3924609,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Georgia",
# latitude: 32.3293809,
# longitude: -83.1137366,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Afghanistan",
# latitude: 33.7680065,
# longitude: 66.2385139,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Turkey",
# latitude: 38.9597594,
# longitude: 34.9249653,
# scale: 0.5
# },

# %%
# Doing the same for EURO ATLANTIC COUNTRIES
humanitarianCountries = [
    ['United States', 'Japan'],
    ['United States', 'Yemen'],
    ['United States', 'Venezuela'],
    ['United States', 'Syria'],
    ['Taiwan', 'United States'],
    
    ['United Kingdom', 'Vanuatu'],
    ['United Kingdom', 'Yemen'],
    ['United Kingdom', 'Bangladesh'],
    ['United Kingdom', 'Sudan'],
    ['United Kingdom', 'Uganda'],
    
    ['Germany', 'Zimbabwe'],
    ['France', 'Syria'],
]

# %%
for countries in humanitarianCountries:
    latLongA = getLatLong(countries[0])
    latLongB = getLatLong(countries[1])
    print("{ latitudes: ["+latLongA[0]+", "+latLongB[0]+"], longitudes: ["+latLongA[1]+", "+latLongB[1]+"]},")
# Out:
# { latitudes: [39.7837304, 36.5748441], longitudes: [-100.4458825, 139.2394179]},
# { latitudes: [39.7837304, 16.3471243], longitudes: [-100.4458825, 47.8915271]},
# { latitudes: [39.7837304, 8.0018709], longitudes: [-100.4458825, -66.1109318]},
# { latitudes: [39.7837304, 34.6401861], longitudes: [-100.4458825, 39.0494106]},
# { latitudes: [23.59829785, 39.7837304], longitudes: [120.83536313817521, -100.4458825]},
# { latitudes: [54.7023545, -16.5255069], longitudes: [-3.2765753, 168.1069154]},
# { latitudes: [54.7023545, 16.3471243], longitudes: [-3.2765753, 47.8915271]},
# { latitudes: [54.7023545, 24.4768783], longitudes: [-3.2765753, 90.2932426]},
# { latitudes: [54.7023545, 14.5844444], longitudes: [-3.2765753, 29.4917691]},
# { latitudes: [54.7023545, 1.5333554], longitudes: [-3.2765753, 32.2166578]},
# { latitudes: [51.0834196, -18.4554963], longitudes: [10.4234469, 29.7468414]},
# { latitudes: [46.603354, 34.6401861], longitudes: [1.8883335, 39.0494106]},

# %%
def remove_duplicates(l):
    return list(set(l))

allCountries = [item for sublist in humanitarianCountries for item in sublist]
uniqueCountries = remove_duplicates(allCountries)

for country in uniqueCountries:
    latLong = getLatLong(country)
    print('{')
    print('svgPath: targetSVG,')
    print('title: "'+country+'",')
    print('latitude: '+latLong[0]+',')
    print('longitude: '+latLong[1]+',')
    print('scale: 0.5')
    print('},')
# Out:
# {
# svgPath: targetSVG,
# title: "United States",
# latitude: 39.7837304,
# longitude: -100.4458825,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Uganda",
# latitude: 1.5333554,
# longitude: 32.2166578,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Bangladesh",
# latitude: 24.4768783,
# longitude: 90.2932426,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Sudan",
# latitude: 14.5844444,
# longitude: 29.4917691,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "France",
# latitude: 46.603354,
# longitude: 1.8883335,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Venezuela",
# latitude: 8.0018709,
# longitude: -66.1109318,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "United Kingdom",
# latitude: 54.7023545,
# longitude: -3.2765753,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Germany",
# latitude: 51.0834196,
# longitude: 10.4234469,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Zimbabwe",
# latitude: -18.4554963,
# longitude: 29.7468414,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Taiwan",
# latitude: 23.59829785,
# longitude: 120.83536313817521,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Vanuatu",
# latitude: -16.5255069,
# longitude: 168.1069154,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Japan",
# latitude: 36.5748441,
# longitude: 139.2394179,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Syria",
# latitude: 34.6401861,
# longitude: 39.0494106,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Yemen",
# latitude: 16.3471243,
# longitude: 47.8915271,
# scale: 0.5
# },

# %%
# Doing the same for GULF DONORS

humanitarianCountries = [
    ['United Arab Emirates', 'Yemen'],
    ['United Arab Emirates', 'Iran'],
    ['United Arab Emirates', 'Kazakhstan'],
    ['United Arab Emirates', 'Iraq'],
    ['United Arab Emirates', 'South Africa'],
    ['United Arab Emirates', 'Sudan'],
    ['Qatar', 'Sudan'],
    ['Qatar', 'Vanuatu'],
    ['Qatar', 'Ethiopia'],
    ['Qatar', 'Rwanda'],
    ['Saudi Arabia', 'Lebanon'],
    ['Saudi Arabia', 'Palestine'],
]

# %%
for countries in humanitarianCountries:
    latLongA = getLatLong(countries[0])
    latLongB = getLatLong(countries[1])
    print("{ latitudes: ["+latLongA[0]+", "+latLongB[0]+"], longitudes: ["+latLongA[1]+", "+latLongB[1]+"]},")
# Out:
# { latitudes: [24.0002488, 16.3471243], longitudes: [53.9994829, 47.8915271]},
# { latitudes: [24.0002488, 32.6475314], longitudes: [53.9994829, 54.5643516]},
# { latitudes: [24.0002488, 47.2286086], longitudes: [53.9994829, 65.2093197]},
# { latitudes: [24.0002488, 33.0955793], longitudes: [53.9994829, 44.1749775]},
# { latitudes: [24.0002488, -28.8166236], longitudes: [53.9994829, 24.991639]},
# { latitudes: [24.0002488, 14.5844444], longitudes: [53.9994829, 29.4917691]},
# { latitudes: [25.3336984, 14.5844444], longitudes: [51.2295295, 29.4917691]},
# { latitudes: [25.3336984, -16.5255069], longitudes: [51.2295295, 168.1069154]},
# { latitudes: [25.3336984, 10.2116702], longitudes: [51.2295295, 38.6521203]},
# { latitudes: [25.3336984, -1.9646631], longitudes: [51.2295295, 30.0644358]},
# { latitudes: [25.6242618, 33.8750629], longitudes: [42.3528328, 35.843409]},
# { latitudes: [25.6242618, 31.462420950000002], longitudes: [42.3528328, 34.27495946066872]},

# %%
def remove_duplicates(l):
    return list(set(l))

allCountries = [item for sublist in humanitarianCountries for item in sublist]
uniqueCountries = remove_duplicates(allCountries)

for country in uniqueCountries:
    latLong = getLatLong(country)
    print('{')
    print('svgPath: targetSVG,')
    print('title: "'+country+'",')
    print('latitude: '+latLong[0]+',')
    print('longitude: '+latLong[1]+',')
    print('scale: 0.5')
    print('},')
# Out:
# {
# svgPath: targetSVG,
# title: "Rwanda",
# latitude: -1.9646631,
# longitude: 30.0644358,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Vanuatu",
# latitude: -16.5255069,
# longitude: 168.1069154,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Iraq",
# latitude: 33.0955793,
# longitude: 44.1749775,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Lebanon",
# latitude: 33.8750629,
# longitude: 35.843409,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Sudan",
# latitude: 14.5844444,
# longitude: 29.4917691,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "United Arab Emirates",
# latitude: 24.0002488,
# longitude: 53.9994829,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "South Africa",
# latitude: -28.8166236,
# longitude: 24.991639,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Ethiopia",
# latitude: 10.2116702,
# longitude: 38.6521203,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Saudi Arabia",
# latitude: 25.6242618,
# longitude: 42.3528328,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Palestine",
# latitude: 31.462420950000002,
# longitude: 34.27495946066872,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Kazakhstan",
# latitude: 47.2286086,
# longitude: 65.2093197,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Qatar",
# latitude: 25.3336984,
# longitude: 51.2295295,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Iran",
# latitude: 32.6475314,
# longitude: 54.5643516,
# scale: 0.5
# },
# {
# svgPath: targetSVG,
# title: "Yemen",
# latitude: 16.3471243,
# longitude: 47.8915271,
# scale: 0.5
# },

# %% [markdown]
# ## Conclusion
#
# The insights from the TF-IDF into what the articles were talking about was generally better than topic modelling for our use case, mainly because we mapped just a few topics from topic modelling exercise. We were able to filter out interesting keywords and get the data on direction of aid ready for visualisation.
